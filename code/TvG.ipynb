# %%
import glob
import pandas as pd
import numpy as np
import tensorflow as tf
import re
import nltk
import threading
import gensim
import logging
import random
from gensim.models import FastText
from gensim.similarities.index import AnnoyIndexer
from gensim.models import Phrases
from gensim.models.phrases import Phraser
from gensim.models.word2vec import LineSentence

# %%
import glob
import os
import six
import threading
from gensim.models import KeyedVectors

from sortedcontainers import SortedDict
from collections import defaultdict, Counter
#from functools32 import lru_cache

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
# %pwd
# Out:
# '/Users/melvinwevers/Dropbox/source/Shico_2/data'

# %%
data = '../../../datasets/tvg_data/'
path2 = 'test2'
allFiles = glob.glob(data + "/**/*.txt", recursive=True)
tokenizer = nltk.data.load('tokenizers/punkt/dutch.pickle')

# %%
def cleaning(text):
    text = re.sub("[^a-zA-Z]"," ", text)
    words = text.lower().split()
    return(words)

def article_to_sentences(text):
    #raw_sentences = tokenizer.tokenize(text.strip())
    sentences = []
    for doc in text:
        raw_sentences = doc.split('.')
        for raw_sentence in raw_sentences:
            if len(raw_sentence) > 0:
                sentences.append(cleaning(raw_sentence))
    return sentences

# %%
def getSentences():
    for file_ in allFiles:
        documents = ''
        with open(file_, 'r') as f:
            documents.append(f.read().replace('\n', ' '))
            sentences = article_to_sentences(documents)
            with open(file_"Output.txt", "w") as text_file:
                text_file.write(sentences)
            #sentences = [item for sublist in sentences for item in sublist]
            #bigram_transformer = gensim.models.Phrases(sentences)
            #bigram = gensim.models.phrases.Phraser(bigram_transformer)
            #corpus = list(bigram[sentences])
    return sentences
        

def getSentencesInRange(startY, endY):
    return [s for year in range(startY, endY) for s in getSentencesForYear(year)]
# Out:
#   File "<ipython-input-258-cb6d66f28e32>", line 7
#     with open(file_"Output.txt", "w") as text_file:
#                               ^
# SyntaxError: invalid syntax

# %%
import pickle
corpus = []
for fname in os.listdir(data):
    documents = []
    path = os.path.join(data, fname)
    if os.path.isdir(path):
        allFiles = sorted(glob.glob(path + "/*.txt", recursive=True))
        for file_ in allFiles:
            with open(file_, 'r') as f:
                documents.append(f.read().replace('\n', ' '))  
        sentences = article_to_sentences(documents)
    corpus.append(sentences)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-342-75c4b16ffee3> in <module>()
#      12     corpus.append(sentences)
#      13 dump_ = open('corpus.pkl', 'w')
# ---> 14 pickle.dump(corpus, dump_)
#      15
#      16
#
# TypeError: write() argument must be str, not bytes

# %%
with open ('outfile', 'rb') as fp:
    itemlist = pickle.load(fp)

# %%
corpus = [item for sublist in corpus for item in sublist]
bigram_transformer = gensim.models.Phrases(corpus, min_count=10)
bigram = gensim.models.phrases.Phraser(bigram_transformer)
corpus_ = list(bigram[corpus])
# Out:
# 2018-06-22 13:25:21,866 : INFO : collecting all words and their counts
# 2018-06-22 13:25:21,875 : INFO : PROGRESS: at sentence #0, processed 0 words and 0 word types
# 2018-06-22 13:25:21,968 : INFO : PROGRESS: at sentence #10000, processed 52826 words and 508 word types
# 2018-06-22 13:25:22,051 : INFO : PROGRESS: at sentence #20000, processed 105366 words and 542 word types
# 2018-06-22 13:25:22,133 : INFO : PROGRESS: at sentence #30000, processed 158585 words and 557 word types
# 2018-06-22 13:25:22,209 : INFO : PROGRESS: at sentence #40000, processed 211145 words and 568 word types
# 2018-06-22 13:25:22,282 : INFO : PROGRESS: at sentence #50000, processed 262228 words and 593 word types
# 2018-06-22 13:25:22,354 : INFO : PROGRESS: at sentence #60000, processed 310105 words and 600 word types
# 2018-06-22 13:25:22,422 : INFO : PROGRESS: at sentence #70000, processed 360346 words and 603 word types
# 2018-06-22 13:25:22,488 : INFO : PROGRESS: at sentence #80000, processed 411157 words and 606 word types
# 2018-06-22 13:25:22,558 : INFO : PROGRESS: at sentence #90000, processed 464654 words and 609 word types
# 2018-06-22 13:25:22,627 : INFO : PROGRESS: at sentence #100000, processed 516499 words and 611 word types
# 2018-06-22 13:25:22,702 : INFO : PROGRESS: at sentence #110000, processed 567738 words and 615 word types
# 2018-06-22 13:25:22,773 : INFO : PROGRESS: at sentence #120000, processed 619534 words and 620 word types
# 2018-06-22 13:25:22,847 : INFO : PROGRESS: at sentence #130000, processed 672750 words and 623 word types
# 2018-06-22 13:25:22,931 : INFO : PROGRESS: at sentence #140000, processed 725389 words and 623 word types
# 2018-06-22 13:25:23,000 : INFO : PROGRESS: at sentence #150000, processed 776791 words and 630 word types
# 2018-06-22 13:25:23,062 : INFO : PROGRESS: at sentence #160000, processed 826636 words and 635 word types
# 2018-06-22 13:25:23,131 : INFO : PROGRESS: at sentence #170000, processed 878271 words and 637 word types
# 2018-06-22 13:25:23,204 : INFO : PROGRESS: at sentence #180000, processed 930612 words and 639 word types
# 2018-06-22 13:25:23,271 : INFO : PROGRESS: at sentence #190000, processed 982344 words and 640 word types
# 2018-06-22 13:25:23,337 : INFO : PROGRESS: at sentence #200000, processed 1035364 words and 643 word types
# 2018-06-22 13:25:23,402 : INFO : PROGRESS: at sentence #210000, processed 1087419 words and 644 word types
# 2018-06-22 13:25:23,478 : INFO : PROGRESS: at sentence #220000, processed 1139173 words and 644 word types
# 2018-06-22 13:25:23,544 : INFO : PROGRESS: at sentence #230000, processed 1191122 words and 644 word types
# 2018-06-22 13:25:23,620 : INFO : PROGRESS: at sentence #240000, processed 1241390 words and 645 word types
# 2018-06-22 13:25:23,693 : INFO : PROGRESS: at sentence #250000, processed 1291767 words and 645 word types
# 2018-06-22 13:25:23,762 : INFO : PROGRESS: at sentence #260000, processed 1344418 words and 646 word types
# 2018-06-22 13:25:23,831 : INFO : PROGRESS: at sentence #270000, processed 1397978 words and 646 word types
# 2018-06-22 13:25:23,902 : INFO : PROGRESS: at sentence #280000, processed 1449917 words and 647 word types
# 2018-06-22 13:25:23,968 : INFO : PROGRESS: at sentence #290000, processed 1501817 words and 648 word types
# 2018-06-22 13:25:24,035 : INFO : PROGRESS: at sentence #300000, processed 1554106 words and 648 word types
# 2018-06-22 13:25:24,106 : INFO : PROGRESS: at sentence #310000, processed 1607147 words and 648 word types
# 2018-06-22 13:25:24,179 : INFO : PROGRESS: at sentence #320000, processed 1660754 words and 648 word types
# 2018-06-22 13:25:24,247 : INFO : PROGRESS: at sentence #330000, processed 1713202 words and 650 word types
# 2018-06-22 13:25:24,314 : INFO : PROGRESS: at sentence #340000, processed 1766057 words and 651 word types
# 2018-06-22 13:25:24,380 : INFO : PROGRESS: at sentence #350000, processed 1818695 words and 652 word types
# 2018-06-22 13:25:24,449 : INFO : PROGRESS: at sentence #360000, processed 1870850 words and 652 word types
# 2018-06-22 13:25:24,519 : INFO : PROGRESS: at sentence #370000, processed 1923035 words and 652 word types
# 2018-06-22 13:25:24,586 : INFO : PROGRESS: at sentence #380000, processed 1976525 words and 654 word types
# 2018-06-22 13:25:24,653 : INFO : PROGRESS: at sentence #390000, processed 2029480 words and 654 word types
# 2018-06-22 13:25:24,726 : INFO : PROGRESS: at sentence #400000, processed 2082799 words and 654 word types
# 2018-06-22 13:25:24,798 : INFO : PROGRESS: at sentence #410000, processed 2136422 words and 654 word types
# 2018-06-22 13:25:24,867 : INFO : PROGRESS: at sentence #420000, processed 2189757 words and 654 word types
# 2018-06-22 13:25:24,935 : INFO : PROGRESS: at sentence #430000, processed 2242040 words and 654 word types
# 2018-06-22 13:25:25,003 : INFO : PROGRESS: at sentence #440000, processed 2292773 words and 654 word types
# 2018-06-22 13:25:25,063 : INFO : PROGRESS: at sentence #450000, processed 2342068 words and 656 word types
# 2018-06-22 13:25:25,124 : INFO : PROGRESS: at sentence #460000, processed 2390415 words and 658 word types
# 2018-06-22 13:25:25,188 : INFO : PROGRESS: at sentence #470000, processed 2442274 words and 658 word types
# 2018-06-22 13:25:25,254 : INFO : PROGRESS: at sentence #480000, processed 2495650 words and 658 word types
# 2018-06-22 13:25:25,322 : INFO : PROGRESS: at sentence #490000, processed 2548584 words and 658 word types
# 2018-06-22 13:25:25,389 : INFO : PROGRESS: at sentence #500000, processed 2600998 words and 658 word types
# 2018-06-22 13:25:25,457 : INFO : PROGRESS: at sentence #510000, processed 2654649 words and 658 word types
# 2018-06-22 13:25:25,520 : INFO : PROGRESS: at sentence #520000, processed 2705855 words and 658 word types
# 2018-06-22 13:25:25,584 : INFO : PROGRESS: at sentence #530000, processed 2755048 words and 658 word types
# 2018-06-22 13:25:25,645 : INFO : PROGRESS: at sentence #540000, processed 2803934 words and 658 word types
# 2018-06-22 13:25:25,710 : INFO : PROGRESS: at sentence #550000, processed 2854296 words and 658 word types
# 2018-06-22 13:25:25,774 : INFO : PROGRESS: at sentence #560000, processed 2907176 words and 658 word types
# 2018-06-22 13:25:25,839 : INFO : PROGRESS: at sentence #570000, processed 2959573 words and 658 word types
# 2018-06-22 13:25:25,904 : INFO : PROGRESS: at sentence #580000, processed 3011430 words and 658 word types
# 2018-06-22 13:25:25,969 : INFO : PROGRESS: at sentence #590000, processed 3062931 words and 658 word types
# 2018-06-22 13:25:26,033 : INFO : PROGRESS: at sentence #600000, processed 3114959 words and 658 word types
# 2018-06-22 13:25:26,100 : INFO : PROGRESS: at sentence #610000, processed 3168501 words and 658 word types
# 2018-06-22 13:25:26,164 : INFO : PROGRESS: at sentence #620000, processed 3220578 words and 658 word types
# 2018-06-22 13:25:26,226 : INFO : PROGRESS: at sentence #630000, processed 3270342 words and 658 word types
# 2018-06-22 13:25:26,288 : INFO : PROGRESS: at sentence #640000, processed 3321629 words and 658 word types
# 2018-06-22 13:25:26,355 : INFO : PROGRESS: at sentence #650000, processed 3373512 words and 658 word types
# 2018-06-22 13:25:26,419 : INFO : PROGRESS: at sentence #660000, processed 3424900 words and 658 word types
# 2018-06-22 13:25:26,487 : INFO : PROGRESS: at sentence #670000, processed 3478460 words and 658 word types
# 2018-06-22 13:25:26,553 : INFO : PROGRESS: at sentence #680000, processed 3530637 words and 658 word types
# 2018-06-22 13:25:26,616 : INFO : PROGRESS: at sentence #690000, processed 3582991 words and 658 word types
# 2018-06-22 13:25:26,681 : INFO : PROGRESS: at sentence #700000, processed 3634416 words and 658 word types
# 2018-06-22 13:25:26,745 : INFO : PROGRESS: at sentence #710000, processed 3685786 words and 658 word types
# 2018-06-22 13:25:26,807 : INFO : PROGRESS: at sentence #720000, processed 3735676 words and 658 word types
# 2018-06-22 13:25:26,873 : INFO : PROGRESS: at sentence #730000, processed 3786544 words and 658 word types
# 2018-06-22 13:25:26,942 : INFO : PROGRESS: at sentence #740000, processed 3840472 words and 658 word types
# 2018-06-22 13:25:27,008 : INFO : PROGRESS: at sentence #750000, processed 3892723 words and 658 word types
# 2018-06-22 13:25:27,072 : INFO : PROGRESS: at sentence #760000, processed 3944631 words and 658 word types
# 2018-06-22 13:25:27,137 : INFO : PROGRESS: at sentence #770000, processed 3997115 words and 658 word types
# 2018-06-22 13:25:27,203 : INFO : PROGRESS: at sentence #780000, processed 4049674 words and 658 word types
# 2018-06-22 13:25:27,270 : INFO : PROGRESS: at sentence #790000, processed 4103337 words and 658 word types
# 2018-06-22 13:25:27,336 : INFO : PROGRESS: at sentence #800000, processed 4156130 words and 658 word types
# 2018-06-22 13:25:27,403 : INFO : PROGRESS: at sentence #810000, processed 4208506 words and 658 word types
# 2018-06-22 13:25:27,472 : INFO : PROGRESS: at sentence #820000, processed 4261776 words and 658 word types
# 2018-06-22 13:25:27,538 : INFO : PROGRESS: at sentence #830000, processed 4313637 words and 658 word types
# 2018-06-22 13:25:27,619 : INFO : PROGRESS: at sentence #840000, processed 4365221 words and 658 word types
# 2018-06-22 13:25:27,705 : INFO : PROGRESS: at sentence #850000, processed 4419195 words and 658 word types
# 2018-06-22 13:25:27,773 : INFO : PROGRESS: at sentence #860000, processed 4472335 words and 658 word types
# 2018-06-22 13:25:27,843 : INFO : PROGRESS: at sentence #870000, processed 4524947 words and 658 word types
# 2018-06-22 13:25:27,918 : INFO : PROGRESS: at sentence #880000, processed 4578721 words and 658 word types
# 2018-06-22 13:25:27,989 : INFO : PROGRESS: at sentence #890000, processed 4632532 words and 658 word types
# 2018-06-22 13:25:28,056 : INFO : PROGRESS: at sentence #900000, processed 4685246 words and 658 word types
# 2018-06-22 13:25:28,126 : INFO : PROGRESS: at sentence #910000, processed 4736511 words and 658 word types
# 2018-06-22 13:25:28,187 : INFO : PROGRESS: at sentence #920000, processed 4786214 words and 658 word types
# 2018-06-22 13:25:28,247 : INFO : PROGRESS: at sentence #930000, processed 4833756 words and 658 word types
# 2018-06-22 13:25:28,315 : INFO : PROGRESS: at sentence #940000, processed 4885526 words and 658 word types
# 2018-06-22 13:25:28,388 : INFO : PROGRESS: at sentence #950000, processed 4937749 words and 658 word types
# 2018-06-22 13:25:28,461 : INFO : PROGRESS: at sentence #960000, processed 4990978 words and 658 word types
# 2018-06-22 13:25:28,533 : INFO : PROGRESS: at sentence #970000, processed 5043389 words and 658 word types
# 2018-06-22 13:25:28,602 : INFO : PROGRESS: at sentence #980000, processed 5097106 words and 658 word types
# 2018-06-22 13:25:28,678 : INFO : PROGRESS: at sentence #990000, processed 5148929 words and 658 word types
# 2018-06-22 13:25:28,743 : INFO : PROGRESS: at sentence #1000000, processed 5199690 words and 658 word types
# 2018-06-22 13:25:28,804 : INFO : PROGRESS: at sentence #1010000, processed 5247790 words and 658 word types
# 2018-06-22 13:25:28,867 : INFO : PROGRESS: at sentence #1020000, processed 5298393 words and 658 word types
# 2018-06-22 13:25:28,931 : INFO : PROGRESS: at sentence #1030000, processed 5349374 words and 658 word types
# 2018-06-22 13:25:29,000 : INFO : PROGRESS: at sentence #1040000, processed 5402810 words and 658 word types
# 2018-06-22 13:25:29,065 : INFO : PROGRESS: at sentence #1050000, processed 5454580 words and 658 word types
# 2018-06-22 13:25:29,132 : INFO : PROGRESS: at sentence #1060000, processed 5505807 words and 658 word types
# 2018-06-22 13:25:29,196 : INFO : PROGRESS: at sentence #1070000, processed 5557546 words and 658 word types
# 2018-06-22 13:25:29,264 : INFO : PROGRESS: at sentence #1080000, processed 5610852 words and 658 word types
# 2018-06-22 13:25:29,332 : INFO : PROGRESS: at sentence #1090000, processed 5663559 words and 658 word types
# 2018-06-22 13:25:29,396 : INFO : PROGRESS: at sentence #1100000, processed 5714675 words and 658 word types
# 2018-06-22 13:25:29,460 : INFO : PROGRESS: at sentence #1110000, processed 5764476 words and 658 word types
# 2018-06-22 13:25:29,526 : INFO : PROGRESS: at sentence #1120000, processed 5816180 words and 658 word types
# 2018-06-22 13:25:29,593 : INFO : PROGRESS: at sentence #1130000, processed 5868372 words and 658 word types
# 2018-06-22 13:25:29,661 : INFO : PROGRESS: at sentence #1140000, processed 5920685 words and 658 word types
# 2018-06-22 13:25:29,727 : INFO : PROGRESS: at sentence #1150000, processed 5973335 words and 658 word types
# 2018-06-22 13:25:29,791 : INFO : PROGRESS: at sentence #1160000, processed 6025609 words and 658 word types
# 2018-06-22 13:25:29,856 : INFO : PROGRESS: at sentence #1170000, processed 6077049 words and 658 word types
# 2018-06-22 13:25:29,921 : INFO : PROGRESS: at sentence #1180000, processed 6129116 words and 658 word types
# 2018-06-22 13:25:29,985 : INFO : PROGRESS: at sentence #1190000, processed 6179160 words and 658 word types
# 2018-06-22 13:25:30,051 : INFO : PROGRESS: at sentence #1200000, processed 6229615 words and 658 word types
# 2018-06-22 13:25:30,130 : INFO : PROGRESS: at sentence #1210000, processed 6282396 words and 658 word types
# 2018-06-22 13:25:30,210 : INFO : PROGRESS: at sentence #1220000, processed 6336103 words and 658 word types
# 2018-06-22 13:25:30,279 : INFO : PROGRESS: at sentence #1230000, processed 6388023 words and 658 word types
# 2018-06-22 13:25:30,345 : INFO : PROGRESS: at sentence #1240000, processed 6439883 words and 658 word types
# 2018-06-22 13:25:30,410 : INFO : PROGRESS: at sentence #1250000, processed 6491934 words and 658 word types
# 2018-06-22 13:25:30,478 : INFO : PROGRESS: at sentence #1260000, processed 6545227 words and 658 word types
# 2018-06-22 13:25:30,547 : INFO : PROGRESS: at sentence #1270000, processed 6598842 words and 658 word types
# 2018-06-22 13:25:30,625 : INFO : PROGRESS: at sentence #1280000, processed 6651283 words and 658 word types
# 2018-06-22 13:25:30,710 : INFO : PROGRESS: at sentence #1290000, processed 6704012 words and 658 word types
# 2018-06-22 13:25:30,779 : INFO : PROGRESS: at sentence #1300000, processed 6756662 words and 658 word types
# 2018-06-22 13:25:30,843 : INFO : PROGRESS: at sentence #1310000, processed 6808752 words and 658 word types
# 2018-06-22 13:25:30,910 : INFO : PROGRESS: at sentence #1320000, processed 6860920 words and 658 word types
# 2018-06-22 13:25:31,002 : INFO : PROGRESS: at sentence #1330000, processed 6914532 words and 658 word types
# 2018-06-22 13:25:31,071 : INFO : PROGRESS: at sentence #1340000, processed 6967578 words and 658 word types
# 2018-06-22 13:25:31,140 : INFO : PROGRESS: at sentence #1350000, processed 7020859 words and 658 word types
# 2018-06-22 13:25:31,210 : INFO : PROGRESS: at sentence #1360000, processed 7074630 words and 658 word types
# 2018-06-22 13:25:31,282 : INFO : PROGRESS: at sentence #1370000, processed 7127773 words and 658 word types
# 2018-06-22 13:25:31,361 : INFO : PROGRESS: at sentence #1380000, processed 7179983 words and 658 word types
# 2018-06-22 13:25:31,437 : INFO : PROGRESS: at sentence #1390000, processed 7230128 words and 658 word types
# 2018-06-22 13:25:31,535 : INFO : PROGRESS: at sentence #1400000, processed 7279436 words and 658 word types
# 2018-06-22 13:25:31,601 : INFO : PROGRESS: at sentence #1410000, processed 7328298 words and 658 word types
# 2018-06-22 13:25:31,668 : INFO : PROGRESS: at sentence #1420000, processed 7380461 words and 658 word types
# 2018-06-22 13:25:31,751 : INFO : PROGRESS: at sentence #1430000, processed 7433073 words and 660 word types
# 2018-06-22 13:25:31,818 : INFO : PROGRESS: at sentence #1440000, processed 7485529 words and 661 word types
# 2018-06-22 13:25:31,900 : INFO : PROGRESS: at sentence #1450000, processed 7537593 words and 662 word types
# 2018-06-22 13:25:31,973 : INFO : PROGRESS: at sentence #1460000, processed 7591755 words and 663 word types
# 2018-06-22 13:25:32,046 : INFO : PROGRESS: at sentence #1470000, processed 7645041 words and 663 word types
# 2018-06-22 13:25:32,114 : INFO : PROGRESS: at sentence #1480000, processed 7697231 words and 666 word types
# 2018-06-22 13:25:32,180 : INFO : PROGRESS: at sentence #1490000, processed 7747656 words and 667 word types
# 2018-06-22 13:25:32,260 : INFO : PROGRESS: at sentence #1500000, processed 7800989 words and 668 word types
# 2018-06-22 13:25:32,343 : INFO : PROGRESS: at sentence #1510000, processed 7853910 words and 668 word types
# 2018-06-22 13:25:32,413 : INFO : PROGRESS: at sentence #1520000, processed 7906836 words and 668 word types
# 2018-06-22 13:25:32,487 : INFO : PROGRESS: at sentence #1530000, processed 7959971 words and 668 word types
# 2018-06-22 13:25:32,561 : INFO : PROGRESS: at sentence #1540000, processed 8012848 words and 669 word types
# 2018-06-22 13:25:32,631 : INFO : PROGRESS: at sentence #1550000, processed 8065190 words and 669 word types
# 2018-06-22 13:25:32,700 : INFO : PROGRESS: at sentence #1560000, processed 8117631 words and 670 word types
# 2018-06-22 13:25:32,771 : INFO : PROGRESS: at sentence #1570000, processed 8170437 words and 672 word types
# 2018-06-22 13:25:32,980 : INFO : PROGRESS: at sentence #1580000, processed 8223087 words and 672 word types
# 2018-06-22 13:25:33,082 : INFO : PROGRESS: at sentence #1590000, processed 8274343 words and 672 word types
# 2018-06-22 13:25:33,163 : INFO : PROGRESS: at sentence #1600000, processed 8324919 words and 672 word types
# 2018-06-22 13:25:33,256 : INFO : PROGRESS: at sentence #1610000, processed 8376368 words and 673 word types
# 2018-06-22 13:25:33,346 : INFO : PROGRESS: at sentence #1620000, processed 8428787 words and 675 word types
# 2018-06-22 13:25:33,425 : INFO : PROGRESS: at sentence #1630000, processed 8482900 words and 676 word types
# 2018-06-22 13:25:33,493 : INFO : PROGRESS: at sentence #1640000, processed 8533756 words and 676 word types
# 2018-06-22 13:25:33,565 : INFO : PROGRESS: at sentence #1650000, processed 8585200 words and 676 word types
# 2018-06-22 13:25:33,637 : INFO : PROGRESS: at sentence #1660000, processed 8637529 words and 676 word types
# 2018-06-22 13:25:33,706 : INFO : PROGRESS: at sentence #1670000, processed 8688817 words and 676 word types
# 2018-06-22 13:25:33,778 : INFO : PROGRESS: at sentence #1680000, processed 8741165 words and 676 word types
# 2018-06-22 13:25:33,848 : INFO : PROGRESS: at sentence #1690000, processed 8793575 words and 677 word types
# 2018-06-22 13:25:33,919 : INFO : PROGRESS: at sentence #1700000, processed 8846122 words and 677 word types
# 2018-06-22 13:25:33,999 : INFO : PROGRESS: at sentence #1710000, processed 8898527 words and 677 word types
# 2018-06-22 13:25:34,080 : INFO : PROGRESS: at sentence #1720000, processed 8948096 words and 677 word types
# 2018-06-22 13:25:34,155 : INFO : PROGRESS: at sentence #1730000, processed 8999910 words and 677 word types
# 2018-06-22 13:25:34,236 : INFO : PROGRESS: at sentence #1740000, processed 9050417 words and 677 word types
# 2018-06-22 13:25:34,310 : INFO : PROGRESS: at sentence #1750000, processed 9100910 words and 677 word types
# 2018-06-22 13:25:34,394 : INFO : PROGRESS: at sentence #1760000, processed 9148797 words and 678 word types
# 2018-06-22 13:25:34,468 : INFO : PROGRESS: at sentence #1770000, processed 9196787 words and 678 word types
# 2018-06-22 13:25:34,547 : INFO : PROGRESS: at sentence #1780000, processed 9245129 words and 679 word types
# 2018-06-22 13:25:34,635 : INFO : PROGRESS: at sentence #1790000, processed 9296078 words and 679 word types
# 2018-06-22 13:25:34,720 : INFO : PROGRESS: at sentence #1800000, processed 9349540 words and 679 word types
# 2018-06-22 13:25:34,797 : INFO : PROGRESS: at sentence #1810000, processed 9402429 words and 679 word types
# 2018-06-22 13:25:34,884 : INFO : PROGRESS: at sentence #1820000, processed 9454868 words and 679 word types
# 2018-06-22 13:25:34,980 : INFO : PROGRESS: at sentence #1830000, processed 9508503 words and 679 word types
# 2018-06-22 13:25:35,057 : INFO : PROGRESS: at sentence #1840000, processed 9559654 words and 679 word types
# 2018-06-22 13:25:35,119 : INFO : PROGRESS: at sentence #1850000, processed 9608821 words and 679 word types
# 2018-06-22 13:25:35,195 : INFO : PROGRESS: at sentence #1860000, processed 9657744 words and 679 word types
# 2018-06-22 13:25:35,273 : INFO : PROGRESS: at sentence #1870000, processed 9708115 words and 679 word types
# 2018-06-22 13:25:35,347 : INFO : PROGRESS: at sentence #1880000, processed 9760962 words and 679 word types
# 2018-06-22 13:25:35,418 : INFO : PROGRESS: at sentence #1890000, processed 9813481 words and 679 word types
# 2018-06-22 13:25:35,491 : INFO : PROGRESS: at sentence #1900000, processed 9865266 words and 679 word types
# 2018-06-22 13:25:35,560 : INFO : PROGRESS: at sentence #1910000, processed 9916835 words and 679 word types
# 2018-06-22 13:25:35,633 : INFO : PROGRESS: at sentence #1920000, processed 9968849 words and 679 word types
# 2018-06-22 13:25:35,703 : INFO : PROGRESS: at sentence #1930000, processed 10022299 words and 679 word types
# 2018-06-22 13:25:35,772 : INFO : PROGRESS: at sentence #1940000, processed 10074488 words and 679 word types
# 2018-06-22 13:25:35,840 : INFO : PROGRESS: at sentence #1950000, processed 10124030 words and 679 word types
# 2018-06-22 13:25:35,913 : INFO : PROGRESS: at sentence #1960000, processed 10175504 words and 679 word types
# 2018-06-22 13:25:35,988 : INFO : PROGRESS: at sentence #1970000, processed 10227398 words and 679 word types
# 2018-06-22 13:25:36,072 : INFO : PROGRESS: at sentence #1980000, processed 10278707 words and 679 word types
# 2018-06-22 13:25:36,156 : INFO : PROGRESS: at sentence #1990000, processed 10332302 words and 679 word types
# 2018-06-22 13:25:36,225 : INFO : PROGRESS: at sentence #2000000, processed 10384470 words and 679 word types
# 2018-06-22 13:25:36,288 : INFO : PROGRESS: at sentence #2010000, processed 10436830 words and 679 word types
# 2018-06-22 13:25:36,354 : INFO : PROGRESS: at sentence #2020000, processed 10488252 words and 679 word types
# 2018-06-22 13:25:36,424 : INFO : PROGRESS: at sentence #2030000, processed 10539653 words and 679 word types
# 2018-06-22 13:25:36,490 : INFO : PROGRESS: at sentence #2040000, processed 10589457 words and 679 word types
# 2018-06-22 13:25:36,562 : INFO : PROGRESS: at sentence #2050000, processed 10640545 words and 679 word types
# 2018-06-22 13:25:36,634 : INFO : PROGRESS: at sentence #2060000, processed 10694388 words and 679 word types
# 2018-06-22 13:25:36,705 : INFO : PROGRESS: at sentence #2070000, processed 10746564 words and 679 word types
# 2018-06-22 13:25:36,772 : INFO : PROGRESS: at sentence #2080000, processed 10798463 words and 679 word types
# 2018-06-22 13:25:36,841 : INFO : PROGRESS: at sentence #2090000, processed 10850928 words and 679 word types
# 2018-06-22 13:25:36,907 : INFO : PROGRESS: at sentence #2100000, processed 10903551 words and 679 word types
# 2018-06-22 13:25:36,976 : INFO : PROGRESS: at sentence #2110000, processed 10957156 words and 679 word types
# 2018-06-22 13:25:37,044 : INFO : PROGRESS: at sentence #2120000, processed 11009980 words and 679 word types
# 2018-06-22 13:25:37,121 : INFO : PROGRESS: at sentence #2130000, processed 11062478 words and 679 word types
# 2018-06-22 13:25:37,201 : INFO : PROGRESS: at sentence #2140000, processed 11115642 words and 679 word types
# 2018-06-22 13:25:37,266 : INFO : PROGRESS: at sentence #2150000, processed 11167586 words and 679 word types
# 2018-06-22 13:25:37,332 : INFO : PROGRESS: at sentence #2160000, processed 11219101 words and 679 word types
# 2018-06-22 13:25:37,400 : INFO : PROGRESS: at sentence #2170000, processed 11273060 words and 679 word types
# 2018-06-22 13:25:37,467 : INFO : PROGRESS: at sentence #2180000, processed 11326301 words and 679 word types
# 2018-06-22 13:25:37,536 : INFO : PROGRESS: at sentence #2190000, processed 11378791 words and 679 word types
# 2018-06-22 13:25:37,604 : INFO : PROGRESS: at sentence #2200000, processed 11432594 words and 679 word types
# 2018-06-22 13:25:37,681 : INFO : PROGRESS: at sentence #2210000, processed 11486345 words and 679 word types
# 2018-06-22 13:25:37,754 : INFO : PROGRESS: at sentence #2220000, processed 11539014 words and 679 word types
# 2018-06-22 13:25:37,831 : INFO : PROGRESS: at sentence #2230000, processed 11590282 words and 679 word types
# 2018-06-22 13:25:37,898 : INFO : PROGRESS: at sentence #2240000, processed 11640013 words and 679 word types
# 2018-06-22 13:25:37,961 : INFO : PROGRESS: at sentence #2250000, processed 11687621 words and 679 word types
# 2018-06-22 13:25:38,033 : INFO : PROGRESS: at sentence #2260000, processed 11739370 words and 679 word types
# 2018-06-22 13:25:38,100 : INFO : PROGRESS: at sentence #2270000, processed 11791588 words and 679 word types
# 2018-06-22 13:25:38,173 : INFO : PROGRESS: at sentence #2280000, processed 11844926 words and 679 word types
# 2018-06-22 13:25:38,238 : INFO : PROGRESS: at sentence #2290000, processed 11897211 words and 679 word types
# 2018-06-22 13:25:38,305 : INFO : PROGRESS: at sentence #2300000, processed 11950991 words and 679 word types
# 2018-06-22 13:25:38,376 : INFO : PROGRESS: at sentence #2310000, processed 12002923 words and 679 word types
# 2018-06-22 13:25:38,448 : INFO : PROGRESS: at sentence #2320000, processed 12053465 words and 679 word types
# 2018-06-22 13:25:38,508 : INFO : PROGRESS: at sentence #2330000, processed 12101578 words and 679 word types
# 2018-06-22 13:25:38,571 : INFO : PROGRESS: at sentence #2340000, processed 12152194 words and 679 word types
# 2018-06-22 13:25:38,636 : INFO : PROGRESS: at sentence #2350000, processed 12203269 words and 679 word types
# 2018-06-22 13:25:38,705 : INFO : PROGRESS: at sentence #2360000, processed 12256607 words and 679 word types
# 2018-06-22 13:25:38,773 : INFO : PROGRESS: at sentence #2370000, processed 12308440 words and 679 word types
# 2018-06-22 13:25:38,837 : INFO : PROGRESS: at sentence #2380000, processed 12359652 words and 679 word types
# 2018-06-22 13:25:38,902 : INFO : PROGRESS: at sentence #2390000, processed 12411421 words and 679 word types
# 2018-06-22 13:25:38,972 : INFO : PROGRESS: at sentence #2400000, processed 12464712 words and 679 word types
# 2018-06-22 13:25:39,042 : INFO : PROGRESS: at sentence #2410000, processed 12517476 words and 679 word types
# 2018-06-22 13:25:39,107 : INFO : PROGRESS: at sentence #2420000, processed 12568378 words and 679 word types
# 2018-06-22 13:25:39,173 : INFO : PROGRESS: at sentence #2430000, processed 12618290 words and 679 word types
# 2018-06-22 13:25:39,240 : INFO : PROGRESS: at sentence #2440000, processed 12670025 words and 679 word types
# 2018-06-22 13:25:39,305 : INFO : PROGRESS: at sentence #2450000, processed 12722214 words and 679 word types
# 2018-06-22 13:25:39,371 : INFO : PROGRESS: at sentence #2460000, processed 12774563 words and 679 word types
# 2018-06-22 13:25:39,436 : INFO : PROGRESS: at sentence #2470000, processed 12827186 words and 679 word types
# 2018-06-22 13:25:39,503 : INFO : PROGRESS: at sentence #2480000, processed 12879459 words and 679 word types
# 2018-06-22 13:25:39,568 : INFO : PROGRESS: at sentence #2490000, processed 12930846 words and 679 word types
# 2018-06-22 13:25:39,637 : INFO : PROGRESS: at sentence #2500000, processed 12983019 words and 679 word types
# 2018-06-22 13:25:39,700 : INFO : PROGRESS: at sentence #2510000, processed 13032999 words and 679 word types
# 2018-06-22 13:25:39,764 : INFO : PROGRESS: at sentence #2520000, processed 13083341 words and 679 word types
# 2018-06-22 13:25:39,829 : INFO : PROGRESS: at sentence #2530000, processed 13136254 words and 679 word types
# 2018-06-22 13:25:39,896 : INFO : PROGRESS: at sentence #2540000, processed 13189925 words and 679 word types
# 2018-06-22 13:25:39,963 : INFO : PROGRESS: at sentence #2550000, processed 13241840 words and 679 word types
# 2018-06-22 13:25:40,038 : INFO : PROGRESS: at sentence #2560000, processed 13293742 words and 679 word types
# 2018-06-22 13:25:40,112 : INFO : PROGRESS: at sentence #2570000, processed 13345773 words and 679 word types
# 2018-06-22 13:25:40,177 : INFO : PROGRESS: at sentence #2580000, processed 13399159 words and 679 word types
# 2018-06-22 13:25:40,245 : INFO : PROGRESS: at sentence #2590000, processed 13452807 words and 679 word types
# 2018-06-22 13:25:40,309 : INFO : PROGRESS: at sentence #2600000, processed 13505093 words and 679 word types
# 2018-06-22 13:25:40,377 : INFO : PROGRESS: at sentence #2610000, processed 13557900 words and 679 word types
# 2018-06-22 13:25:40,442 : INFO : PROGRESS: at sentence #2620000, processed 13610530 words and 679 word types
# 2018-06-22 13:25:40,508 : INFO : PROGRESS: at sentence #2630000, processed 13662596 words and 679 word types
# 2018-06-22 13:25:40,576 : INFO : PROGRESS: at sentence #2640000, processed 13714797 words and 679 word types
# 2018-06-22 13:25:40,647 : INFO : PROGRESS: at sentence #2650000, processed 13768353 words and 679 word types
# 2018-06-22 13:25:40,716 : INFO : PROGRESS: at sentence #2660000, processed 13821454 words and 679 word types
# 2018-06-22 13:25:40,784 : INFO : PROGRESS: at sentence #2670000, processed 13874724 words and 679 word types
# 2018-06-22 13:25:40,854 : INFO : PROGRESS: at sentence #2680000, processed 13928574 words and 679 word types
# 2018-06-22 13:25:40,919 : INFO : PROGRESS: at sentence #2690000, processed 13981694 words and 679 word types
# 2018-06-22 13:25:40,992 : INFO : PROGRESS: at sentence #2700000, processed 14033873 words and 679 word types
# 2018-06-22 13:25:41,054 : INFO : PROGRESS: at sentence #2710000, processed 14083947 words and 679 word types
# 2018-06-22 13:25:41,119 : INFO : PROGRESS: at sentence #2720000, processed 14133107 words and 679 word types
# 2018-06-22 13:25:41,187 : INFO : PROGRESS: at sentence #2730000, processed 14182157 words and 679 word types
# 2018-06-22 13:25:41,254 : INFO : PROGRESS: at sentence #2740000, processed 14234340 words and 679 word types
# 2018-06-22 13:25:41,323 : INFO : PROGRESS: at sentence #2750000, processed 14287701 words and 679 word types
# 2018-06-22 13:25:41,390 : INFO : PROGRESS: at sentence #2760000, processed 14340258 words and 679 word types
# 2018-06-22 13:25:41,459 : INFO : PROGRESS: at sentence #2770000, processed 14393306 words and 679 word types
# 2018-06-22 13:25:41,528 : INFO : PROGRESS: at sentence #2780000, processed 14446432 words and 679 word types
# 2018-06-22 13:25:41,593 : INFO : PROGRESS: at sentence #2790000, processed 14497516 words and 679 word types
# 2018-06-22 13:25:41,655 : INFO : PROGRESS: at sentence #2800000, processed 14546109 words and 679 word types
# 2018-06-22 13:25:41,719 : INFO : PROGRESS: at sentence #2810000, processed 14595530 words and 679 word types
# 2018-06-22 13:25:41,782 : INFO : PROGRESS: at sentence #2820000, processed 14646058 words and 679 word types
# 2018-06-22 13:25:41,855 : INFO : PROGRESS: at sentence #2830000, processed 14699313 words and 679 word types
# 2018-06-22 13:25:41,939 : INFO : PROGRESS: at sentence #2840000, processed 14751458 words and 679 word types
# 2018-06-22 13:25:42,011 : INFO : PROGRESS: at sentence #2850000, processed 14803059 words and 679 word types
# 2018-06-22 13:25:42,077 : INFO : PROGRESS: at sentence #2860000, processed 14854781 words and 679 word types
# 2018-06-22 13:25:42,143 : INFO : PROGRESS: at sentence #2870000, processed 14907451 words and 679 word types
# 2018-06-22 13:25:42,212 : INFO : PROGRESS: at sentence #2880000, processed 14960245 words and 679 word types
# 2018-06-22 13:25:42,282 : INFO : PROGRESS: at sentence #2890000, processed 15012435 words and 679 word types
# 2018-06-22 13:25:42,347 : INFO : PROGRESS: at sentence #2900000, processed 15061455 words and 679 word types
# 2018-06-22 13:25:42,422 : INFO : PROGRESS: at sentence #2910000, processed 15113274 words and 679 word types
# 2018-06-22 13:25:42,516 : INFO : PROGRESS: at sentence #2920000, processed 15165438 words and 679 word types
# 2018-06-22 13:25:42,603 : INFO : PROGRESS: at sentence #2930000, processed 15216726 words and 679 word types
# 2018-06-22 13:25:42,675 : INFO : PROGRESS: at sentence #2940000, processed 15270336 words and 679 word types
# 2018-06-22 13:25:42,741 : INFO : PROGRESS: at sentence #2950000, processed 15322325 words and 679 word types
# 2018-06-22 13:25:42,811 : INFO : PROGRESS: at sentence #2960000, processed 15374262 words and 679 word types
# 2018-06-22 13:25:42,880 : INFO : PROGRESS: at sentence #2970000, processed 15425987 words and 679 word types
# 2018-06-22 13:25:42,952 : INFO : PROGRESS: at sentence #2980000, processed 15477141 words and 679 word types
# 2018-06-22 13:25:43,016 : INFO : PROGRESS: at sentence #2990000, processed 15527487 words and 679 word types
# 2018-06-22 13:25:43,083 : INFO : PROGRESS: at sentence #3000000, processed 15578751 words and 679 word types
# 2018-06-22 13:25:43,150 : INFO : PROGRESS: at sentence #3010000, processed 15632435 words and 679 word types
# 2018-06-22 13:25:43,215 : INFO : PROGRESS: at sentence #3020000, processed 15684836 words and 679 word types
# 2018-06-22 13:25:43,284 : INFO : PROGRESS: at sentence #3030000, processed 15736556 words and 679 word types
# 2018-06-22 13:25:43,351 : INFO : PROGRESS: at sentence #3040000, processed 15788921 words and 679 word types
# 2018-06-22 13:25:43,421 : INFO : PROGRESS: at sentence #3050000, processed 15841709 words and 679 word types
# 2018-06-22 13:25:43,494 : INFO : PROGRESS: at sentence #3060000, processed 15895443 words and 679 word types
# 2018-06-22 13:25:43,563 : INFO : PROGRESS: at sentence #3070000, processed 15948087 words and 679 word types
# 2018-06-22 13:25:43,628 : INFO : PROGRESS: at sentence #3080000, processed 16000739 words and 679 word types
# 2018-06-22 13:25:43,694 : INFO : PROGRESS: at sentence #3090000, processed 16054140 words and 679 word types
# 2018-06-22 13:25:43,761 : INFO : PROGRESS: at sentence #3100000, processed 16105836 words and 679 word types
# 2018-06-22 13:25:43,825 : INFO : PROGRESS: at sentence #3110000, processed 16157174 words and 679 word types
# 2018-06-22 13:25:43,896 : INFO : PROGRESS: at sentence #3120000, processed 16211134 words and 679 word types
# 2018-06-22 13:25:43,966 : INFO : PROGRESS: at sentence #3130000, processed 16264188 words and 679 word types
# 2018-06-22 13:25:44,034 : INFO : PROGRESS: at sentence #3140000, processed 16316893 words and 679 word types
# 2018-06-22 13:25:44,104 : INFO : PROGRESS: at sentence #3150000, processed 16370842 words and 679 word types
# 2018-06-22 13:25:44,172 : INFO : PROGRESS: at sentence #3160000, processed 16424271 words and 679 word types
# 2018-06-22 13:25:44,238 : INFO : PROGRESS: at sentence #3170000, processed 16477104 words and 679 word types
# 2018-06-22 13:25:44,307 : INFO : PROGRESS: at sentence #3180000, processed 16528153 words and 679 word types
# 2018-06-22 13:25:44,368 : INFO : PROGRESS: at sentence #3190000, processed 16577469 words and 679 word types
# 2018-06-22 13:25:44,430 : INFO : PROGRESS: at sentence #3200000, processed 16625225 words and 679 word types
# 2018-06-22 13:25:44,496 : INFO : PROGRESS: at sentence #3210000, processed 16677113 words and 679 word types
# 2018-06-22 13:25:44,564 : INFO : PROGRESS: at sentence #3220000, processed 16729831 words and 679 word types
# 2018-06-22 13:25:44,633 : INFO : PROGRESS: at sentence #3230000, processed 16782988 words and 679 word types
# 2018-06-22 13:25:44,701 : INFO : PROGRESS: at sentence #3240000, processed 16835310 words and 679 word types
# 2018-06-22 13:25:44,768 : INFO : PROGRESS: at sentence #3250000, processed 16889196 words and 679 word types
# 2018-06-22 13:25:44,832 : INFO : PROGRESS: at sentence #3260000, processed 16941436 words and 679 word types
# 2018-06-22 13:25:44,893 : INFO : PROGRESS: at sentence #3270000, processed 16990930 words and 679 word types
# 2018-06-22 13:25:44,953 : INFO : PROGRESS: at sentence #3280000, processed 17039173 words and 679 word types
# 2018-06-22 13:25:45,018 : INFO : PROGRESS: at sentence #3290000, processed 17090134 words and 679 word types
# 2018-06-22 13:25:45,083 : INFO : PROGRESS: at sentence #3300000, processed 17141675 words and 679 word types
# 2018-06-22 13:25:45,150 : INFO : PROGRESS: at sentence #3310000, processed 17194475 words and 679 word types
# 2018-06-22 13:25:45,216 : INFO : PROGRESS: at sentence #3320000, processed 17246391 words and 679 word types
# 2018-06-22 13:25:45,280 : INFO : PROGRESS: at sentence #3330000, processed 17297750 words and 679 word types
# 2018-06-22 13:25:45,352 : INFO : PROGRESS: at sentence #3340000, processed 17349686 words and 679 word types
# 2018-06-22 13:25:45,421 : INFO : PROGRESS: at sentence #3350000, processed 17402824 words and 679 word types
# 2018-06-22 13:25:45,489 : INFO : PROGRESS: at sentence #3360000, processed 17455545 words and 679 word types
# 2018-06-22 13:25:45,550 : INFO : PROGRESS: at sentence #3370000, processed 17506095 words and 679 word types
# 2018-06-22 13:25:45,617 : INFO : PROGRESS: at sentence #3380000, processed 17556275 words and 679 word types
# 2018-06-22 13:25:45,683 : INFO : PROGRESS: at sentence #3390000, processed 17608255 words and 679 word types
# 2018-06-22 13:25:45,749 : INFO : PROGRESS: at sentence #3400000, processed 17659989 words and 679 word types
# 2018-06-22 13:25:45,815 : INFO : PROGRESS: at sentence #3410000, processed 17712898 words and 679 word types
# 2018-06-22 13:25:45,884 : INFO : PROGRESS: at sentence #3420000, processed 17765255 words and 679 word types
# 2018-06-22 13:25:45,950 : INFO : PROGRESS: at sentence #3430000, processed 17817674 words and 679 word types
# 2018-06-22 13:25:46,016 : INFO : PROGRESS: at sentence #3440000, processed 17869204 words and 679 word types
# 2018-06-22 13:25:46,081 : INFO : PROGRESS: at sentence #3450000, processed 17920858 words and 679 word types
# 2018-06-22 13:25:46,144 : INFO : PROGRESS: at sentence #3460000, processed 17970584 words and 679 word types
# 2018-06-22 13:25:46,207 : INFO : PROGRESS: at sentence #3470000, processed 18021061 words and 679 word types
# 2018-06-22 13:25:46,273 : INFO : PROGRESS: at sentence #3480000, processed 18074604 words and 679 word types
# 2018-06-22 13:25:46,344 : INFO : PROGRESS: at sentence #3490000, processed 18127890 words and 679 word types
# 2018-06-22 13:25:46,409 : INFO : PROGRESS: at sentence #3500000, processed 18179721 words and 679 word types
# 2018-06-22 13:25:46,479 : INFO : PROGRESS: at sentence #3510000, processed 18231769 words and 679 word types
# 2018-06-22 13:25:46,549 : INFO : PROGRESS: at sentence #3520000, processed 18283916 words and 679 word types
# 2018-06-22 13:25:46,617 : INFO : PROGRESS: at sentence #3530000, processed 18337769 words and 679 word types
# 2018-06-22 13:25:46,684 : INFO : PROGRESS: at sentence #3540000, processed 18391039 words and 679 word types
# 2018-06-22 13:25:46,749 : INFO : PROGRESS: at sentence #3550000, processed 18443232 words and 679 word types
# 2018-06-22 13:25:46,815 : INFO : PROGRESS: at sentence #3560000, processed 18495999 words and 679 word types
# 2018-06-22 13:25:46,881 : INFO : PROGRESS: at sentence #3570000, processed 18548423 words and 679 word types
# 2018-06-22 13:25:46,947 : INFO : PROGRESS: at sentence #3580000, processed 18600429 words and 679 word types
# 2018-06-22 13:25:47,012 : INFO : PROGRESS: at sentence #3590000, processed 18653120 words and 679 word types
# 2018-06-22 13:25:47,081 : INFO : PROGRESS: at sentence #3600000, processed 18706904 words and 679 word types
# 2018-06-22 13:25:47,148 : INFO : PROGRESS: at sentence #3610000, processed 18759581 words and 679 word types
# 2018-06-22 13:25:47,214 : INFO : PROGRESS: at sentence #3620000, processed 18812897 words and 679 word types
# 2018-06-22 13:25:47,281 : INFO : PROGRESS: at sentence #3630000, processed 18866957 words and 679 word types
# 2018-06-22 13:25:47,352 : INFO : PROGRESS: at sentence #3640000, processed 18919707 words and 679 word types
# 2018-06-22 13:25:47,420 : INFO : PROGRESS: at sentence #3650000, processed 18971834 words and 679 word types
# 2018-06-22 13:25:47,483 : INFO : PROGRESS: at sentence #3660000, processed 19021610 words and 679 word types
# 2018-06-22 13:25:47,545 : INFO : PROGRESS: at sentence #3670000, processed 19070146 words and 679 word types
# 2018-06-22 13:25:47,610 : INFO : PROGRESS: at sentence #3680000, processed 19120335 words and 679 word types
# 2018-06-22 13:25:47,675 : INFO : PROGRESS: at sentence #3690000, processed 19172943 words and 679 word types
# 2018-06-22 13:25:47,745 : INFO : PROGRESS: at sentence #3700000, processed 19225872 words and 679 word types
# 2018-06-22 13:25:47,814 : INFO : PROGRESS: at sentence #3710000, processed 19278034 words and 679 word types
# 2018-06-22 13:25:47,881 : INFO : PROGRESS: at sentence #3720000, processed 19331284 words and 679 word types
# 2018-06-22 13:25:47,951 : INFO : PROGRESS: at sentence #3730000, processed 19384187 words and 679 word types
# 2018-06-22 13:25:48,018 : INFO : PROGRESS: at sentence #3740000, processed 19435413 words and 679 word types
# 2018-06-22 13:25:48,081 : INFO : PROGRESS: at sentence #3750000, processed 19483215 words and 679 word types
# 2018-06-22 13:25:48,147 : INFO : PROGRESS: at sentence #3760000, processed 19533192 words and 679 word types
# 2018-06-22 13:25:48,215 : INFO : PROGRESS: at sentence #3770000, processed 19583949 words and 679 word types
# 2018-06-22 13:25:48,291 : INFO : PROGRESS: at sentence #3780000, processed 19637426 words and 679 word types
# 2018-06-22 13:25:48,356 : INFO : PROGRESS: at sentence #3790000, processed 19689624 words and 679 word types
# 2018-06-22 13:25:48,421 : INFO : PROGRESS: at sentence #3800000, processed 19740936 words and 679 word types
# 2018-06-22 13:25:48,486 : INFO : PROGRESS: at sentence #3810000, processed 19792581 words and 679 word types
# 2018-06-22 13:25:48,555 : INFO : PROGRESS: at sentence #3820000, processed 19845358 words and 679 word types
# 2018-06-22 13:25:48,623 : INFO : PROGRESS: at sentence #3830000, processed 19898272 words and 679 word types
# 2018-06-22 13:25:48,691 : INFO : PROGRESS: at sentence #3840000, processed 19949980 words and 679 word types
# 2018-06-22 13:25:48,767 : INFO : PROGRESS: at sentence #3850000, processed 19999544 words and 679 word types
# 2018-06-22 13:25:48,845 : INFO : PROGRESS: at sentence #3860000, processed 20051386 words and 679 word types
# 2018-06-22 13:25:48,917 : INFO : PROGRESS: at sentence #3870000, processed 20103596 words and 679 word types
# 2018-06-22 13:25:48,983 : INFO : PROGRESS: at sentence #3880000, processed 20154972 words and 679 word types
# 2018-06-22 13:25:49,057 : INFO : PROGRESS: at sentence #3890000, processed 20208287 words and 679 word types
# 2018-06-22 13:25:49,137 : INFO : PROGRESS: at sentence #3900000, processed 20260203 words and 679 word types
# 2018-06-22 13:25:49,230 : INFO : PROGRESS: at sentence #3910000, processed 20312234 words and 679 word types
# 2018-06-22 13:25:49,322 : INFO : PROGRESS: at sentence #3920000, processed 20363848 words and 679 word types
# 2018-06-22 13:25:49,388 : INFO : PROGRESS: at sentence #3930000, processed 20414811 words and 679 word types
# 2018-06-22 13:25:49,454 : INFO : PROGRESS: at sentence #3940000, processed 20465209 words and 679 word types
# 2018-06-22 13:25:49,521 : INFO : PROGRESS: at sentence #3950000, processed 20516977 words and 679 word types
# 2018-06-22 13:25:49,587 : INFO : PROGRESS: at sentence #3960000, processed 20570730 words and 679 word types
# 2018-06-22 13:25:49,662 : INFO : PROGRESS: at sentence #3970000, processed 20622702 words and 679 word types
# 2018-06-22 13:25:49,731 : INFO : PROGRESS: at sentence #3980000, processed 20674767 words and 679 word types
# 2018-06-22 13:25:49,799 : INFO : PROGRESS: at sentence #3990000, processed 20727014 words and 679 word types
# 2018-06-22 13:25:49,864 : INFO : PROGRESS: at sentence #4000000, processed 20779718 words and 679 word types
# 2018-06-22 13:25:49,934 : INFO : PROGRESS: at sentence #4010000, processed 20833618 words and 679 word types
# 2018-06-22 13:25:49,998 : INFO : PROGRESS: at sentence #4020000, processed 20886128 words and 679 word types
# 2018-06-22 13:25:50,077 : INFO : PROGRESS: at sentence #4030000, processed 20938655 words and 679 word types
# 2018-06-22 13:25:50,148 : INFO : PROGRESS: at sentence #4040000, processed 20992002 words and 679 word types
# 2018-06-22 13:25:50,219 : INFO : PROGRESS: at sentence #4050000, processed 21043809 words and 679 word types
# 2018-06-22 13:25:50,282 : INFO : PROGRESS: at sentence #4060000, processed 21095531 words and 679 word types
# 2018-06-22 13:25:50,351 : INFO : PROGRESS: at sentence #4070000, processed 21149309 words and 679 word types
# 2018-06-22 13:25:50,415 : INFO : PROGRESS: at sentence #4080000, processed 21202292 words and 679 word types
# 2018-06-22 13:25:50,483 : INFO : PROGRESS: at sentence #4090000, processed 21255297 words and 679 word types
# 2018-06-22 13:25:50,551 : INFO : PROGRESS: at sentence #4100000, processed 21309127 words and 679 word types
# 2018-06-22 13:25:50,618 : INFO : PROGRESS: at sentence #4110000, processed 21362353 words and 679 word types
# 2018-06-22 13:25:50,683 : INFO : PROGRESS: at sentence #4120000, processed 21415038 words and 679 word types
# 2018-06-22 13:25:50,748 : INFO : PROGRESS: at sentence #4130000, processed 21465750 words and 679 word types
# 2018-06-22 13:25:50,808 : INFO : PROGRESS: at sentence #4140000, processed 21515124 words and 679 word types
# 2018-06-22 13:25:50,867 : INFO : PROGRESS: at sentence #4150000, processed 21563025 words and 679 word types
# 2018-06-22 13:25:50,933 : INFO : PROGRESS: at sentence #4160000, processed 21615203 words and 679 word types
# 2018-06-22 13:25:50,998 : INFO : PROGRESS: at sentence #4170000, processed 21668172 words and 679 word types
# 2018-06-22 13:25:51,067 : INFO : PROGRESS: at sentence #4180000, processed 21721281 words and 679 word types
# 2018-06-22 13:25:51,133 : INFO : PROGRESS: at sentence #4190000, processed 21773698 words and 679 word types
# 2018-06-22 13:25:51,200 : INFO : PROGRESS: at sentence #4200000, processed 21827174 words and 679 word types
# 2018-06-22 13:25:51,266 : INFO : PROGRESS: at sentence #4210000, processed 21878968 words and 679 word types
# 2018-06-22 13:25:51,328 : INFO : PROGRESS: at sentence #4220000, processed 21928318 words and 679 word types
# 2018-06-22 13:25:51,388 : INFO : PROGRESS: at sentence #4230000, processed 21976709 words and 679 word types
# 2018-06-22 13:25:51,452 : INFO : PROGRESS: at sentence #4240000, processed 22027529 words and 679 word types
# 2018-06-22 13:25:51,518 : INFO : PROGRESS: at sentence #4250000, processed 22079985 words and 679 word types
# 2018-06-22 13:25:51,585 : INFO : PROGRESS: at sentence #4260000, processed 22132341 words and 679 word types
# 2018-06-22 13:25:51,649 : INFO : PROGRESS: at sentence #4270000, processed 22184175 words and 679 word types
# 2018-06-22 13:25:51,714 : INFO : PROGRESS: at sentence #4280000, processed 22236026 words and 679 word types
# 2018-06-22 13:25:51,778 : INFO : PROGRESS: at sentence #4290000, processed 22287917 words and 679 word types
# 2018-06-22 13:25:51,845 : INFO : PROGRESS: at sentence #4300000, processed 22341038 words and 679 word types
# 2018-06-22 13:25:51,909 : INFO : PROGRESS: at sentence #4310000, processed 22393478 words and 679 word types
# 2018-06-22 13:25:51,972 : INFO : PROGRESS: at sentence #4320000, processed 22443709 words and 679 word types
# 2018-06-22 13:25:52,034 : INFO : PROGRESS: at sentence #4330000, processed 22494326 words and 679 word types
# 2018-06-22 13:25:52,098 : INFO : PROGRESS: at sentence #4340000, processed 22546229 words and 679 word types
# 2018-06-22 13:25:52,162 : INFO : PROGRESS: at sentence #4350000, processed 22597847 words and 679 word types
# 2018-06-22 13:25:52,229 : INFO : PROGRESS: at sentence #4360000, processed 22651244 words and 679 word types
# 2018-06-22 13:25:52,293 : INFO : PROGRESS: at sentence #4370000, processed 22703480 words and 679 word types
# 2018-06-22 13:25:52,357 : INFO : PROGRESS: at sentence #4380000, processed 22755824 words and 679 word types
# 2018-06-22 13:25:52,420 : INFO : PROGRESS: at sentence #4390000, processed 22807389 words and 679 word types
# 2018-06-22 13:25:52,487 : INFO : PROGRESS: at sentence #4400000, processed 22858774 words and 679 word types
# 2018-06-22 13:25:52,556 : INFO : PROGRESS: at sentence #4410000, processed 22908378 words and 679 word types
# ...
# 2018-06-22 13:31:51,219 : INFO : PROGRESS: at sentence #58710000, processed 297985611 words and 702 word types
# 2018-06-22 13:31:51,282 : INFO : PROGRESS: at sentence #58720000, processed 298034895 words and 702 word types
# 2018-06-22 13:31:51,340 : INFO : PROGRESS: at sentence #58730000, processed 298082521 words and 702 word types
# 2018-06-22 13:31:51,401 : INFO : PROGRESS: at sentence #58740000, processed 298132193 words and 702 word types
# 2018-06-22 13:31:51,463 : INFO : PROGRESS: at sentence #58750000, processed 298182737 words and 702 word types
# 2018-06-22 13:31:51,525 : INFO : PROGRESS: at sentence #58760000, processed 298232680 words and 702 word types
# 2018-06-22 13:31:51,587 : INFO : PROGRESS: at sentence #58770000, processed 298282291 words and 702 word types
# 2018-06-22 13:31:51,648 : INFO : PROGRESS: at sentence #58780000, processed 298331867 words and 702 word types
# 2018-06-22 13:31:51,712 : INFO : PROGRESS: at sentence #58790000, processed 298384407 words and 702 word types
# 2018-06-22 13:31:51,779 : INFO : PROGRESS: at sentence #58800000, processed 298437347 words and 702 word types
# 2018-06-22 13:31:51,844 : INFO : PROGRESS: at sentence #58810000, processed 298488993 words and 702 word types
# 2018-06-22 13:31:51,905 : INFO : PROGRESS: at sentence #58820000, processed 298539796 words and 702 word types
# 2018-06-22 13:31:51,967 : INFO : PROGRESS: at sentence #58830000, processed 298589512 words and 702 word types
# 2018-06-22 13:31:52,028 : INFO : PROGRESS: at sentence #58840000, processed 298638700 words and 702 word types
# 2018-06-22 13:31:52,088 : INFO : PROGRESS: at sentence #58850000, processed 298688660 words and 702 word types
# 2018-06-22 13:31:52,150 : INFO : PROGRESS: at sentence #58860000, processed 298739098 words and 702 word types
# 2018-06-22 13:31:52,213 : INFO : PROGRESS: at sentence #58870000, processed 298789694 words and 702 word types
# 2018-06-22 13:31:52,278 : INFO : PROGRESS: at sentence #58880000, processed 298840318 words and 702 word types
# 2018-06-22 13:31:52,342 : INFO : PROGRESS: at sentence #58890000, processed 298890466 words and 702 word types
# 2018-06-22 13:31:52,407 : INFO : PROGRESS: at sentence #58900000, processed 298940909 words and 702 word types
# 2018-06-22 13:31:52,469 : INFO : PROGRESS: at sentence #58910000, processed 298990276 words and 702 word types
# 2018-06-22 13:31:52,532 : INFO : PROGRESS: at sentence #58920000, processed 299040869 words and 702 word types
# 2018-06-22 13:31:52,593 : INFO : PROGRESS: at sentence #58930000, processed 299089693 words and 702 word types
# 2018-06-22 13:31:52,656 : INFO : PROGRESS: at sentence #58940000, processed 299139762 words and 702 word types
# 2018-06-22 13:31:52,715 : INFO : PROGRESS: at sentence #58950000, processed 299188711 words and 702 word types
# 2018-06-22 13:31:52,780 : INFO : PROGRESS: at sentence #58960000, processed 299238469 words and 702 word types
# 2018-06-22 13:31:52,844 : INFO : PROGRESS: at sentence #58970000, processed 299288712 words and 702 word types
# 2018-06-22 13:31:52,904 : INFO : PROGRESS: at sentence #58980000, processed 299335747 words and 702 word types
# 2018-06-22 13:31:52,963 : INFO : PROGRESS: at sentence #58990000, processed 299384444 words and 702 word types
# 2018-06-22 13:31:53,027 : INFO : PROGRESS: at sentence #59000000, processed 299432609 words and 702 word types
# 2018-06-22 13:31:53,087 : INFO : PROGRESS: at sentence #59010000, processed 299482123 words and 702 word types
# 2018-06-22 13:31:53,155 : INFO : PROGRESS: at sentence #59020000, processed 299531291 words and 702 word types
# 2018-06-22 13:31:53,218 : INFO : PROGRESS: at sentence #59030000, processed 299582178 words and 702 word types
# 2018-06-22 13:31:53,280 : INFO : PROGRESS: at sentence #59040000, processed 299628996 words and 702 word types
# 2018-06-22 13:31:53,342 : INFO : PROGRESS: at sentence #59050000, processed 299678035 words and 702 word types
# 2018-06-22 13:31:53,399 : INFO : PROGRESS: at sentence #59060000, processed 299724993 words and 702 word types
# 2018-06-22 13:31:53,461 : INFO : PROGRESS: at sentence #59070000, processed 299772892 words and 702 word types
# 2018-06-22 13:31:53,525 : INFO : PROGRESS: at sentence #59080000, processed 299822239 words and 702 word types
# 2018-06-22 13:31:53,587 : INFO : PROGRESS: at sentence #59090000, processed 299871831 words and 702 word types
# 2018-06-22 13:31:53,648 : INFO : PROGRESS: at sentence #59100000, processed 299921055 words and 702 word types
# 2018-06-22 13:31:53,712 : INFO : PROGRESS: at sentence #59110000, processed 299971189 words and 702 word types
# 2018-06-22 13:31:53,774 : INFO : PROGRESS: at sentence #59120000, processed 300020440 words and 702 word types
# 2018-06-22 13:31:53,834 : INFO : PROGRESS: at sentence #59130000, processed 300067760 words and 702 word types
# 2018-06-22 13:31:53,895 : INFO : PROGRESS: at sentence #59140000, processed 300117200 words and 702 word types
# 2018-06-22 13:31:53,955 : INFO : PROGRESS: at sentence #59150000, processed 300164690 words and 702 word types
# 2018-06-22 13:31:54,017 : INFO : PROGRESS: at sentence #59160000, processed 300214259 words and 702 word types
# 2018-06-22 13:31:54,077 : INFO : PROGRESS: at sentence #59170000, processed 300264066 words and 702 word types
# 2018-06-22 13:31:54,138 : INFO : PROGRESS: at sentence #59180000, processed 300313791 words and 702 word types
# 2018-06-22 13:31:54,198 : INFO : PROGRESS: at sentence #59190000, processed 300361112 words and 702 word types
# 2018-06-22 13:31:54,260 : INFO : PROGRESS: at sentence #59200000, processed 300409937 words and 702 word types
# 2018-06-22 13:31:54,321 : INFO : PROGRESS: at sentence #59210000, processed 300456911 words and 702 word types
# 2018-06-22 13:31:54,380 : INFO : PROGRESS: at sentence #59220000, processed 300505182 words and 702 word types
# 2018-06-22 13:31:54,445 : INFO : PROGRESS: at sentence #59230000, processed 300554990 words and 702 word types
# 2018-06-22 13:31:54,507 : INFO : PROGRESS: at sentence #59240000, processed 300603714 words and 702 word types
# 2018-06-22 13:31:54,571 : INFO : PROGRESS: at sentence #59250000, processed 300653372 words and 702 word types
# 2018-06-22 13:31:54,635 : INFO : PROGRESS: at sentence #59260000, processed 300703626 words and 702 word types
# 2018-06-22 13:31:54,696 : INFO : PROGRESS: at sentence #59270000, processed 300751485 words and 702 word types
# 2018-06-22 13:31:54,755 : INFO : PROGRESS: at sentence #59280000, processed 300799632 words and 702 word types
# 2018-06-22 13:31:54,814 : INFO : PROGRESS: at sentence #59290000, processed 300848154 words and 702 word types
# 2018-06-22 13:31:54,879 : INFO : PROGRESS: at sentence #59300000, processed 300897123 words and 702 word types
# 2018-06-22 13:31:54,943 : INFO : PROGRESS: at sentence #59310000, processed 300946387 words and 702 word types
# 2018-06-22 13:31:55,007 : INFO : PROGRESS: at sentence #59320000, processed 300996963 words and 702 word types
# 2018-06-22 13:31:55,065 : INFO : PROGRESS: at sentence #59330000, processed 301044159 words and 702 word types
# 2018-06-22 13:31:55,124 : INFO : PROGRESS: at sentence #59340000, processed 301093002 words and 702 word types
# 2018-06-22 13:31:55,185 : INFO : PROGRESS: at sentence #59350000, processed 301140812 words and 702 word types
# 2018-06-22 13:31:55,246 : INFO : PROGRESS: at sentence #59360000, processed 301188334 words and 702 word types
# 2018-06-22 13:31:55,309 : INFO : PROGRESS: at sentence #59370000, processed 301238968 words and 702 word types
# 2018-06-22 13:31:55,371 : INFO : PROGRESS: at sentence #59380000, processed 301287501 words and 702 word types
# 2018-06-22 13:31:55,433 : INFO : PROGRESS: at sentence #59390000, processed 301337032 words and 702 word types
# 2018-06-22 13:31:55,502 : INFO : PROGRESS: at sentence #59400000, processed 301387397 words and 702 word types
# 2018-06-22 13:31:55,566 : INFO : PROGRESS: at sentence #59410000, processed 301437843 words and 702 word types
# 2018-06-22 13:31:55,628 : INFO : PROGRESS: at sentence #59420000, processed 301488481 words and 702 word types
# 2018-06-22 13:31:55,693 : INFO : PROGRESS: at sentence #59430000, processed 301538286 words and 702 word types
# 2018-06-22 13:31:55,757 : INFO : PROGRESS: at sentence #59440000, processed 301588568 words and 702 word types
# 2018-06-22 13:31:55,819 : INFO : PROGRESS: at sentence #59450000, processed 301639109 words and 702 word types
# 2018-06-22 13:31:55,885 : INFO : PROGRESS: at sentence #59460000, processed 301689295 words and 702 word types
# 2018-06-22 13:31:55,948 : INFO : PROGRESS: at sentence #59470000, processed 301738147 words and 702 word types
# 2018-06-22 13:31:56,011 : INFO : PROGRESS: at sentence #59480000, processed 301786190 words and 702 word types
# 2018-06-22 13:31:56,074 : INFO : PROGRESS: at sentence #59490000, processed 301835886 words and 702 word types
# 2018-06-22 13:31:56,137 : INFO : PROGRESS: at sentence #59500000, processed 301884330 words and 702 word types
# 2018-06-22 13:31:56,198 : INFO : PROGRESS: at sentence #59510000, processed 301932701 words and 702 word types
# 2018-06-22 13:31:56,263 : INFO : PROGRESS: at sentence #59520000, processed 301984052 words and 702 word types
# 2018-06-22 13:31:56,328 : INFO : PROGRESS: at sentence #59530000, processed 302035854 words and 702 word types
# 2018-06-22 13:31:56,391 : INFO : PROGRESS: at sentence #59540000, processed 302086958 words and 702 word types
# 2018-06-22 13:31:56,454 : INFO : PROGRESS: at sentence #59550000, processed 302136185 words and 702 word types
# 2018-06-22 13:31:56,517 : INFO : PROGRESS: at sentence #59560000, processed 302185371 words and 702 word types
# 2018-06-22 13:31:56,581 : INFO : PROGRESS: at sentence #59570000, processed 302234341 words and 702 word types
# 2018-06-22 13:31:56,645 : INFO : PROGRESS: at sentence #59580000, processed 302283416 words and 702 word types
# 2018-06-22 13:31:56,713 : INFO : PROGRESS: at sentence #59590000, processed 302334470 words and 702 word types
# 2018-06-22 13:31:56,781 : INFO : PROGRESS: at sentence #59600000, processed 302385076 words and 702 word types
# 2018-06-22 13:31:56,846 : INFO : PROGRESS: at sentence #59610000, processed 302436236 words and 702 word types
# 2018-06-22 13:31:56,912 : INFO : PROGRESS: at sentence #59620000, processed 302487104 words and 702 word types
# 2018-06-22 13:31:56,986 : INFO : PROGRESS: at sentence #59630000, processed 302539654 words and 702 word types
# 2018-06-22 13:31:57,058 : INFO : PROGRESS: at sentence #59640000, processed 302593492 words and 702 word types
# 2018-06-22 13:31:57,131 : INFO : PROGRESS: at sentence #59650000, processed 302643938 words and 702 word types
# 2018-06-22 13:31:57,198 : INFO : PROGRESS: at sentence #59660000, processed 302695230 words and 702 word types
# 2018-06-22 13:31:57,268 : INFO : PROGRESS: at sentence #59670000, processed 302746563 words and 702 word types
# 2018-06-22 13:31:57,333 : INFO : PROGRESS: at sentence #59680000, processed 302798494 words and 702 word types
# 2018-06-22 13:31:57,397 : INFO : PROGRESS: at sentence #59690000, processed 302849262 words and 702 word types
# 2018-06-22 13:31:57,458 : INFO : PROGRESS: at sentence #59700000, processed 302898737 words and 702 word types
# 2018-06-22 13:31:57,522 : INFO : PROGRESS: at sentence #59710000, processed 302946477 words and 702 word types
# 2018-06-22 13:31:57,584 : INFO : PROGRESS: at sentence #59720000, processed 302997285 words and 702 word types
# 2018-06-22 13:31:57,647 : INFO : PROGRESS: at sentence #59730000, processed 303048453 words and 702 word types
# 2018-06-22 13:31:57,715 : INFO : PROGRESS: at sentence #59740000, processed 303099888 words and 702 word types
# 2018-06-22 13:31:57,788 : INFO : PROGRESS: at sentence #59750000, processed 303149606 words and 702 word types
# 2018-06-22 13:31:57,861 : INFO : PROGRESS: at sentence #59760000, processed 303198553 words and 702 word types
# 2018-06-22 13:31:57,924 : INFO : PROGRESS: at sentence #59770000, processed 303247867 words and 702 word types
# 2018-06-22 13:31:57,989 : INFO : PROGRESS: at sentence #59780000, processed 303296997 words and 702 word types
# 2018-06-22 13:31:58,058 : INFO : PROGRESS: at sentence #59790000, processed 303347434 words and 702 word types
# 2018-06-22 13:31:58,125 : INFO : PROGRESS: at sentence #59800000, processed 303398700 words and 702 word types
# 2018-06-22 13:31:58,197 : INFO : PROGRESS: at sentence #59810000, processed 303448825 words and 702 word types
# 2018-06-22 13:31:58,266 : INFO : PROGRESS: at sentence #59820000, processed 303500454 words and 702 word types
# 2018-06-22 13:31:58,331 : INFO : PROGRESS: at sentence #59830000, processed 303551940 words and 702 word types
# 2018-06-22 13:31:58,403 : INFO : PROGRESS: at sentence #59840000, processed 303606042 words and 702 word types
# 2018-06-22 13:31:58,467 : INFO : PROGRESS: at sentence #59850000, processed 303658342 words and 702 word types
# 2018-06-22 13:31:58,530 : INFO : PROGRESS: at sentence #59860000, processed 303707974 words and 702 word types
# 2018-06-22 13:31:58,594 : INFO : PROGRESS: at sentence #59870000, processed 303759074 words and 702 word types
# 2018-06-22 13:31:58,660 : INFO : PROGRESS: at sentence #59880000, processed 303810777 words and 702 word types
# 2018-06-22 13:31:58,726 : INFO : PROGRESS: at sentence #59890000, processed 303862922 words and 702 word types
# 2018-06-22 13:31:58,788 : INFO : PROGRESS: at sentence #59900000, processed 303912452 words and 702 word types
# 2018-06-22 13:31:58,847 : INFO : PROGRESS: at sentence #59910000, processed 303960054 words and 702 word types
# 2018-06-22 13:31:58,908 : INFO : PROGRESS: at sentence #59920000, processed 304010201 words and 702 word types
# 2018-06-22 13:31:58,975 : INFO : PROGRESS: at sentence #59930000, processed 304061371 words and 702 word types
# 2018-06-22 13:31:59,039 : INFO : PROGRESS: at sentence #59940000, processed 304112882 words and 702 word types
# 2018-06-22 13:31:59,100 : INFO : PROGRESS: at sentence #59950000, processed 304163048 words and 702 word types
# 2018-06-22 13:31:59,161 : INFO : PROGRESS: at sentence #59960000, processed 304212360 words and 702 word types
# 2018-06-22 13:31:59,223 : INFO : PROGRESS: at sentence #59970000, processed 304261802 words and 702 word types
# 2018-06-22 13:31:59,284 : INFO : PROGRESS: at sentence #59980000, processed 304310288 words and 702 word types
# 2018-06-22 13:31:59,346 : INFO : PROGRESS: at sentence #59990000, processed 304360104 words and 702 word types
# 2018-06-22 13:31:59,413 : INFO : PROGRESS: at sentence #60000000, processed 304411260 words and 702 word types
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-339-4a4c6c1d5d01> in <module>()
#       1 corpus = [item for sublist in corpus for item in sublist]
# ----> 2 bigram_transformer = gensim.models.Phrases(corpus, min_count=10)
#       3 bigram = gensim.models.phrases.Phraser(bigram_transformer)
#       4 corpus_ = list(bigram[corpus])
#
# ~/anaconda3/lib/python3.6/site-packages/gensim/models/phrases.py in __init__(self, sentences, min_count, threshold, max_vocab_size, delimiter, progress_per, scoring, common_terms)
#     341
#     342         if sentences is not None:
# --> 343             self.add_vocab(sentences)
#     344
#     345     @classmethod
#
# ~/anaconda3/lib/python3.6/site-packages/gensim/models/phrases.py in add_vocab(self, sentences)
#     414         # counts collected in previous learn_vocab runs.
#     415         min_reduce, vocab, total_words = self.learn_vocab(
# --> 416             sentences, self.max_vocab_size, self.delimiter, self.progress_per, self.common_terms)
#     417
#     418         self.corpus_word_count += total_words
#
# ~/anaconda3/lib/python3.6/site-packages/gensim/models/phrases.py in learn_vocab(sentences, max_vocab_size, delimiter, progress_per, common_terms)
#     382             in_between = []
#     383             for word in s:
# --> 384                 if word not in common_terms:
#     385                     vocab[word] += 1
#     386                     if last_uncommon is not None:
#
# KeyboardInterrupt:

# %%
#sentences = gensim.models.word2vec.PathLineSentences('data')

# %%
model = gensim.models.Word2Vec(min_count=10, size = 200, iter=20, alpha=0.025, window = 10, workers =7, sg=1)
#model = gensim.models.FastText(min_count=10, size = 200, iter=10, alpha=0.025, window = 10, workers =7, sg=1)

# %%
model.build_vocab(corpus_)

# %%
model.train(corpus_, total_examples=model.corpus_count, epochs=model.iter)

# %%
model.init_sims(replace=True)
model.wv.save_word2vec_format('tvg', binary=True)

# %%
model.wv.vocab
# Out:
# {'benjamin': <gensim.models.keyedvectors.Vocab at 0x1a2a657e80>,
#  'j': <gensim.models.keyedvectors.Vocab at 0x1a2a657320>,
#  'kaplan': <gensim.models.keyedvectors.Vocab at 0x1a2a657b70>,
#  'hubert': <gensim.models.keyedvectors.Vocab at 0x1a2a657ac8>,
#  'duifhuis': <gensim.models.keyedvectors.Vocab at 0x1a2a657c50>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x1a2a657630>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x1a2a657908>,
#  'nature': <gensim.models.keyedvectors.Vocab at 0x1a2a657a58>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x1a2a657f60>,
#  'dutch': <gensim.models.keyedvectors.Vocab at 0x1a2a6577f0>,
#  'libertinism': <gensim.models.keyedvectors.Vocab at 0x1a2a6575f8>,
#  'ca': <gensim.models.keyedvectors.Vocab at 0x1a2a6578d0>,
#  'l': <gensim.models.keyedvectors.Vocab at 0x1a2a657940>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x1a2a6574a8>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x1acbb14be0>,
#  'occupied': <gensim.models.keyedvectors.Vocab at 0x1acbb147b8>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x1acbb14908>,
#  'modest': <gensim.models.keyedvectors.Vocab at 0x1acbb14dd8>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x1acbb146d8>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x1acbb14d30>,
#  'pantheon': <gensim.models.keyedvectors.Vocab at 0x1acbb14a58>,
#  'national': <gensim.models.keyedvectors.Vocab at 0x1b86d5dfd0>,
#  'heroes': <gensim.models.keyedvectors.Vocab at 0x1cb3187fd0>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x1cb318c1d0>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x1cb318c2e8>,
#  'sure': <gensim.models.keyedvectors.Vocab at 0x1cb318c320>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x1cb318c358>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x1cb318c390>,
#  'found': <gensim.models.keyedvectors.Vocab at 0x1cb318c3c8>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x1cb318c400>,
#  'favor': <gensim.models.keyedvectors.Vocab at 0x1cb318c438>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x1cb318c470>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x1cb318c4a8>,
#  'calvinists': <gensim.models.keyedvectors.Vocab at 0x1cb318c4e0>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x1cb318c518>,
#  'numbered': <gensim.models.keyedvectors.Vocab at 0x1cb318c550>,
#  'among': <gensim.models.keyedvectors.Vocab at 0x1cb318c588>,
#  'most': <gensim.models.keyedvectors.Vocab at 0x1cb318c5c0>,
#  'ardent': <gensim.models.keyedvectors.Vocab at 0x1cb318c5f8>,
#  'opponents': <gensim.models.keyedvectors.Vocab at 0x1cb318c630>,
#  'calvinism': <gensim.models.keyedvectors.Vocab at 0x1cb318c668>,
#  'reformation': <gensim.models.keyedvectors.Vocab at 0x1cb318c6a0>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x1cb318c6d8>,
#  'libertine': <gensim.models.keyedvectors.Vocab at 0x1cb318c710>,
#  'neither': <gensim.models.keyedvectors.Vocab at 0x1cb318c748>,
#  'catholic': <gensim.models.keyedvectors.Vocab at 0x1cb318c780>,
#  'nor': <gensim.models.keyedvectors.Vocab at 0x1cb318c7b8>,
#  'calvinist': <gensim.models.keyedvectors.Vocab at 0x1cb318c7f0>,
#  'member': <gensim.models.keyedvectors.Vocab at 0x1cb318c828>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x1cb318c860>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x1cb318c898>,
#  'defined': <gensim.models.keyedvectors.Vocab at 0x1cb318c8d0>,
#  'denomination': <gensim.models.keyedvectors.Vocab at 0x1cb318c908>,
#  'championed': <gensim.models.keyedvectors.Vocab at 0x1cb318c940>,
#  'cause': <gensim.models.keyedvectors.Vocab at 0x1cb318c978>,
#  'reli': <gensim.models.keyedvectors.Vocab at 0x1cb318c9b0>,
#  'gious': <gensim.models.keyedvectors.Vocab at 0x1cb318c9e8>,
#  'tolerance': <gensim.models.keyedvectors.Vocab at 0x1cb318ca20>,
#  'libertines': <gensim.models.keyedvectors.Vocab at 0x1cb318ca58>,
#  'campaigned': <gensim.models.keyedvectors.Vocab at 0x1cb318ca90>,
#  'against': <gensim.models.keyedvectors.Vocab at 0x1cb318cac8>,
#  'theocratie': <gensim.models.keyedvectors.Vocab at 0x1cb318cb00>,
#  'aspira': <gensim.models.keyedvectors.Vocab at 0x1cb318cb38>,
#  'tions': <gensim.models.keyedvectors.Vocab at 0x1cb318cb70>,
#  'reformers': <gensim.models.keyedvectors.Vocab at 0x1cb318cba8>,
#  'ln': <gensim.models.keyedvectors.Vocab at 0x1cb318cbe0>,
#  'process': <gensim.models.keyedvectors.Vocab at 0x1cb318cc18>,
#  'helped': <gensim.models.keyedvectors.Vocab at 0x1cb318cc50>,
#  'lay': <gensim.models.keyedvectors.Vocab at 0x1cb318cc88>,
#  'foundations': <gensim.models.keyedvectors.Vocab at 0x1cb318ccc0>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x1cb318ccf8>,
#  'religious': <gensim.models.keyedvectors.Vocab at 0x1cb318cd30>,
#  'plural': <gensim.models.keyedvectors.Vocab at 0x1cb318cd68>,
#  'sm': <gensim.models.keyedvectors.Vocab at 0x1cb318cda0>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x1cb318cdd8>,
#  'characterized': <gensim.models.keyedvectors.Vocab at 0x1cb318ce10>,
#  'republic': <gensim.models.keyedvectors.Vocab at 0x1cb318ce48>,
#  'liberal': <gensim.models.keyedvectors.Vocab at 0x1cb318ce80>,
#  'histori': <gensim.models.keyedvectors.Vocab at 0x1cb318ceb8>,
#  'ans': <gensim.models.keyedvectors.Vocab at 0x1cb318cef0>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x1cb318cf28>,
#  'esteemed': <gensim.models.keyedvectors.Vocab at 0x1cb318cf60>,
#  'his': <gensim.models.keyedvectors.Vocab at 0x1cb318cf98>,
#  'efforts': <gensim.models.keyedvectors.Vocab at 0x1cb318cfd0>,
#  'nineteenth': <gensim.models.keyedvectors.Vocab at 0x1a287c2048>,
#  'century': <gensim.models.keyedvectors.Vocab at 0x1a287c2080>,
#  'scholars': <gensim.models.keyedvectors.Vocab at 0x1a287c20b8>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x1a287c20f0>,
#  'hailed': <gensim.models.keyedvectors.Vocab at 0x1a287c2128>,
#  'him': <gensim.models.keyedvectors.Vocab at 0x1a287c2160>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x1a287c2198>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x1a287c21d0>,
#  'embodiment': <gensim.models.keyedvectors.Vocab at 0x1a287c2208>,
#  'tolerant': <gensim.models.keyedvectors.Vocab at 0x1a287c2240>,
#  'volksgeest': <gensim.models.keyedvectors.Vocab at 0x1a287c2278>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x1a287c22b0>,
#  'respect': <gensim.models.keyedvectors.Vocab at 0x1a287c22e8>,
#  'commands': <gensim.models.keyedvectors.Vocab at 0x1a287c2320>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x1a287c2358>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x1a287c2390>,
#  'scholarly': <gensim.models.keyedvectors.Vocab at 0x1a287c23c8>,
#  'attention': <gensim.models.keyedvectors.Vocab at 0x1a287c2400>,
#  'example': <gensim.models.keyedvectors.Vocab at 0x1a287c2438>,
#  'dirck': <gensim.models.keyedvectors.Vocab at 0x1a287c2470>,
#  'coornhert': <gensim.models.keyedvectors.Vocab at 0x1a287c24a8>,
#  'unlike': <gensim.models.keyedvectors.Vocab at 0x1a287c24e0>,
#  'did': <gensim.models.keyedvectors.Vocab at 0x1a287c2518>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x1a287c2550>,
#  'publish': <gensim.models.keyedvectors.Vocab at 0x1a287c2588>,
#  'pamphleteer': <gensim.models.keyedvectors.Vocab at 0x1a287c25c0>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x1a287c25f8>,
#  'preacher': <gensim.models.keyedvectors.Vocab at 0x1a287c2630>,
#  'organizer': <gensim.models.keyedvectors.Vocab at 0x1a287c2668>,
#  'roles': <gensim.models.keyedvectors.Vocab at 0x1a287c26a0>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x1a287c26d8>,
#  'gave': <gensim.models.keyedvectors.Vocab at 0x1a287c2710>,
#  'prominence': <gensim.models.keyedvectors.Vocab at 0x1a287c2748>,
#  'sixteenth': <gensim.models.keyedvectors.Vocab at 0x1a287c2780>,
#  'society': <gensim.models.keyedvectors.Vocab at 0x1a287c27b8>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x1a287c27f0>,
#  'access': <gensim.models.keyedvectors.Vocab at 0x1a287c2828>,
#  'beliefs': <gensim.models.keyedvectors.Vocab at 0x1a287c2860>,
#  'ideas': <gensim.models.keyedvectors.Vocab at 0x1a287c2898>,
#  'harder': <gensim.models.keyedvectors.Vocab at 0x1a287c28d0>,
#  'historians': <gensim.models.keyedvectors.Vocab at 0x1a287c2908>,
#  'caspar': <gensim.models.keyedvectors.Vocab at 0x1a287c2940>,
#  'coolhaes': <gensim.models.keyedvectors.Vocab at 0x1a287c2978>,
#  'herman': <gensim.models.keyedvectors.Vocab at 0x1a287c29b0>,
#  'herbertsz': <gensim.models.keyedvectors.Vocab at 0x1a287c29e8>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x1a287c2a20>,
#  'preachers': <gensim.models.keyedvectors.Vocab at 0x1a287c2a58>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x1a287c2a90>,
#  'had': <gensim.models.keyedvectors.Vocab at 0x1a287c2ac8>,
#  'historiographic': <gensim.models.keyedvectors.Vocab at 0x1a287c2b00>,
#  'misfortune': <gensim.models.keyedvectors.Vocab at 0x1a287c2b38>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x1a287c2b70>,
#  'crucial': <gensim.models.keyedvectors.Vocab at 0x1a287c2ba8>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x1a287c2be0>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x1a287c2c18>,
#  'utrecht': <gensim.models.keyedvectors.Vocab at 0x1a287c2c50>,
#  'outside': <gensim.models.keyedvectors.Vocab at 0x1a287c2c88>,
#  'studied': <gensim.models.keyedvectors.Vocab at 0x1a287c2cc0>,
#  'province': <gensim.models.keyedvectors.Vocab at 0x1a287c2cf8>,
#  'holland': <gensim.models.keyedvectors.Vocab at 0x1a287c2d30>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x1a287c2d68>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x1a287c2da0>,
#  'length': <gensim.models.keyedvectors.Vocab at 0x1a287c2dd8>,
#  'study': <gensim.models.keyedvectors.Vocab at 0x1a287c2e10>,
#  'ofthe': <gensim.models.keyedvectors.Vocab at 0x1a287c2e48>,
#  'appeared': <gensim.models.keyedvectors.Vocab at 0x1a287c2e80>,
#  'monograph': <gensim.models.keyedvectors.Vocab at 0x1a287c2eb8>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x1a287c2ef0>,
#  'result': <gensim.models.keyedvectors.Vocab at 0x1a287c2f28>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x1a287c2f60>,
#  'mentioned': <gensim.models.keyedvectors.Vocab at 0x1a287c2f98>,
#  'almost': <gensim.models.keyedvectors.Vocab at 0x1a287c2fd0>,
#  'briefly': <gensim.models.keyedvectors.Vocab at 0x1a287c4048>,
#  'frequently': <gensim.models.keyedvectors.Vocab at 0x1a287c4080>,
#  'tories': <gensim.models.keyedvectors.Vocab at 0x1a287c40b8>,
#  'netherlands': <gensim.models.keyedvectors.Vocab at 0x1a287c40f0>,
#  'purpose': <gensim.models.keyedvectors.Vocab at 0x1a287c4128>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x1a287c4160>,
#  'article': <gensim.models.keyedvectors.Vocab at 0x1a287c4198>,
#  'fill': <gensim.models.keyedvectors.Vocab at 0x1a287c41d0>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x1a287c4208>,
#  'glaring': <gensim.models.keyedvectors.Vocab at 0x1a287c4240>,
#  'gaps': <gensim.models.keyedvectors.Vocab at 0x1a287c4278>,
#  'our': <gensim.models.keyedvectors.Vocab at 0x1a287c42b0>,
#  'knowledge': <gensim.models.keyedvectors.Vocab at 0x1a287c42e8>,
#  'drawing': <gensim.models.keyedvectors.Vocab at 0x1a287c4320>,
#  'chie': <gensim.models.keyedvectors.Vocab at 0x1a287c4358>,
#  'y': <gensim.models.keyedvectors.Vocab at 0x1a287c4390>,
#  'twenty': <gensim.models.keyedvectors.Vocab at 0x1a287c43c8>,
#  'sermons': <gensim.models.keyedvectors.Vocab at 0x1a287c4400>,
#  'survived': <gensim.models.keyedvectors.Vocab at 0x1a287c4438>,
#  'seventeenth': <gensim.models.keyedvectors.Vocab at 0x1a287c4470>,
#  'transcriptions': <gensim.models.keyedvectors.Vocab at 0x1a287c44a8>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x1a287c44e0>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x1a287c4518>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x1a287c4550>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x1a287c4588>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x1a287c45c0>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x1a287c45f8>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x1a287c4630>,
#  'thank': <gensim.models.keyedvectors.Vocab at 0x1a287c4668>,
#  'nicolette': <gensim.models.keyedvectors.Vocab at 0x1a287c46a0>,
#  'mout': <gensim.models.keyedvectors.Vocab at 0x1a287c46d8>,
#  'steven': <gensim.models.keyedvectors.Vocab at 0x1a287c4710>,
#  'ozment': <gensim.models.keyedvectors.Vocab at 0x1a287c4748>,
#  'woltjer': <gensim.models.keyedvectors.Vocab at 0x1a287c4780>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x1a287c47b8>,
#  'valuable': <gensim.models.keyedvectors.Vocab at 0x1a287c47f0>,
#  'com': <gensim.models.keyedvectors.Vocab at 0x1a287c4828>,
#  'ments': <gensim.models.keyedvectors.Vocab at 0x1a287c4860>,
#  'earlier': <gensim.models.keyedvectors.Vocab at 0x1a287c4898>,
#  'version': <gensim.models.keyedvectors.Vocab at 0x1a287c48d0>,
#  'research': <gensim.models.keyedvectors.Vocab at 0x1a287c4908>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x1a287c4940>,
#  'possible': <gensim.models.keyedvectors.Vocab at 0x1a287c4978>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x1a287c49b0>,
#  'grants': <gensim.models.keyedvectors.Vocab at 0x1a287c49e8>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x1a287c4a20>,
#  'sheldon': <gensim.models.keyedvectors.Vocab at 0x1a287c4a58>,
#  'fund': <gensim.models.keyedvectors.Vocab at 0x1a287c4a90>,
#  'harvard': <gensim.models.keyedvectors.Vocab at 0x1a287c4ac8>,
#  'university': <gensim.models.keyedvectors.Vocab at 0x1a287c4b00>,
#  'joint': <gensim.models.keyedvectors.Vocab at 0x1a287c4b38>,
#  'committee': <gensim.models.keyedvectors.Vocab at 0x1a287c4b70>,
#  'western': <gensim.models.keyedvectors.Vocab at 0x1a287c4ba8>,
#  'europe': <gensim.models.keyedvectors.Vocab at 0x1a287c4be0>,
#  'american': <gensim.models.keyedvectors.Vocab at 0x1a287c4c18>,
#  'coun': <gensim.models.keyedvectors.Vocab at 0x1a287c4c50>,
#  'cil': <gensim.models.keyedvectors.Vocab at 0x1a287c4c88>,
#  'learned': <gensim.models.keyedvectors.Vocab at 0x1a287c4cc0>,
#  'societies': <gensim.models.keyedvectors.Vocab at 0x1a287c4cf8>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x1a287c4d30>,
#  'science': <gensim.models.keyedvectors.Vocab at 0x1a287c4d68>,
#  'council': <gensim.models.keyedvectors.Vocab at 0x1a287c4da0>,
#  'abbreviations': <gensim.models.keyedvectors.Vocab at 0x1a287c4dd8>,
#  'gau': <gensim.models.keyedvectors.Vocab at 0x1a287c4e10>,
#  'gemeentearchief': <gensim.models.keyedvectors.Vocab at 0x1a287c4e48>,
#  'gbr': <gensim.models.keyedvectors.Vocab at 0x1a287c4e80>,
#  'rgr': <gensim.models.keyedvectors.Vocab at 0x1a287c4eb8>,
#  'gemeentebibliotheek': <gensim.models.keyedvectors.Vocab at 0x1a287c4ef0>,
#  'rotterdam': <gensim.models.keyedvectors.Vocab at 0x1a287c4f28>,
#  'bibliotheek': <gensim.models.keyedvectors.Vocab at 0x1a287c4f60>,
#  'der': <gensim.models.keyedvectors.Vocab at 0x1a287c4f98>,
#  'remonstrantsch': <gensim.models.keyedvectors.Vocab at 0x1a287c4fd0>,
#  'gereformeerde': <gensim.models.keyedvectors.Vocab at 0x1a287c7048>,
#  'gemeente': <gensim.models.keyedvectors.Vocab at 0x1a287c7080>,
#  'te': <gensim.models.keyedvectors.Vocab at 0x1a287c70b8>,
#  'wmv': <gensim.models.keyedvectors.Vocab at 0x1a287c70f0>,
#  'werken': <gensim.models.keyedvectors.Vocab at 0x1a287c7128>,
#  'marnix': <gensim.models.keyedvectors.Vocab at 0x1a287c7160>,
#  'vereeniging': <gensim.models.keyedvectors.Vocab at 0x1a287c7198>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x1a287c71d0>,
#  'e': <gensim.models.keyedvectors.Vocab at 0x1a287c7208>,
#  'g': <gensim.models.keyedvectors.Vocab at 0x1a287c7240>,
#  'works': <gensim.models.keyedvectors.Vocab at 0x1a287c7278>,
#  'barend': <gensim.models.keyedvectors.Vocab at 0x1a287c72b0>,
#  'glasius': <gensim.models.keyedvectors.Vocab at 0x1a287c72e8>,
#  'b': <gensim.models.keyedvectors.Vocab at 0x1a287c7320>,
#  'ter': <gensim.models.keyedvectors.Vocab at 0x1a287c7358>,
#  'haar': <gensim.models.keyedvectors.Vocab at 0x1a287c7390>,
#  'cited': <gensim.models.keyedvectors.Vocab at 0x1a287c73c8>,
#  'd': <gensim.models.keyedvectors.Vocab at 0x1a287c7400>,
#  'nauta': <gensim.models.keyedvectors.Vocab at 0x1a287c7438>,
#  'de': <gensim.models.keyedvectors.Vocab at 0x1a287c7470>,
#  'reformatie': <gensim.models.keyedvectors.Vocab at 0x1a287c74a8>,
#  'neder': <gensim.models.keyedvectors.Vocab at 0x1a287c74e0>,
#  'land': <gensim.models.keyedvectors.Vocab at 0x1a287c7518>,
#  'historiogra': <gensim.models.keyedvectors.Vocab at 0x1a287c7550>,
#  'gest': <gensim.models.keyedvectors.Vocab at 0x1a287c7588>,
#  'nederland': <gensim.models.keyedvectors.Vocab at 0x1a287c75c0>,
#  'ed': <gensim.models.keyedvectors.Vocab at 0x1a287c75f8>,
#  'p': <gensim.models.keyedvectors.Vocab at 0x1a287c7630>,
#  'm': <gensim.models.keyedvectors.Vocab at 0x1a287c7668>,
#  'geurts': <gensim.models.keyedvectors.Vocab at 0x1a287c76a0>,
#  'janssen': <gensim.models.keyedvectors.Vocab at 0x1a287c76d8>,
#  'hague': <gensim.models.keyedvectors.Vocab at 0x1a287c7710>,
#  'bl': <gensim.models.keyedvectors.Vocab at 0x1a287c7748>,
#  'll': <gensim.models.keyedvectors.Vocab at 0x1a287c7780>,
#  'originally': <gensim.models.keyedvectors.Vocab at 0x1a287c77b8>,
#  'published': <gensim.models.keyedvectors.Vocab at 0x1a287c77f0>,
#  'hero': <gensim.models.keyedvectors.Vocab at 0x1a287c7828>,
#  'historical': <gensim.models.keyedvectors.Vocab at 0x1a287c7860>,
#  'novel': <gensim.models.keyedvectors.Vocab at 0x1a287c7898>,
#  'diest': <gensim.models.keyedvectors.Vocab at 0x1a287c78d0>,
#  'lorgion': <gensim.models.keyedvectors.Vocab at 0x1a287c7908>,
#  'hubertus': <gensim.models.keyedvectors.Vocab at 0x1a287c7940>,
#  'een': <gensim.models.keyedvectors.Vocab at 0x1a287c7978>,
#  'tafereel': <gensim.models.keyedvectors.Vocab at 0x1a287c79b0>,
#  'uit': <gensim.models.keyedvectors.Vocab at 0x1a287c79e8>,
#  'den': <gensim.models.keyedvectors.Vocab at 0x1a287c7a20>,
#  'tijd': <gensim.models.keyedvectors.Vocab at 0x1a287c7a58>,
#  'kerkhervorming': <gensim.models.keyedvectors.Vocab at 0x1a287c7a90>,
#  'groningen': <gensim.models.keyedvectors.Vocab at 0x1a287c7ac8>,
#  'exception': <gensim.models.keyedvectors.Vocab at 0x1a287c7b00>,
#  'publishing': <gensim.models.keyedvectors.Vocab at 0x1a287c7b38>,
#  'anonymous': <gensim.models.keyedvectors.Vocab at 0x1a287c7b70>,
#  'pamphlet': <gensim.models.keyedvectors.Vocab at 0x1a287c7ba8>,
#  'attributed': <gensim.models.keyedvectors.Vocab at 0x1a287c7be0>,
#  'werner': <gensim.models.keyedvectors.Vocab at 0x1a287c7c18>,
#  'helmichius': <gensim.models.keyedvectors.Vocab at 0x1a287c7c50>,
#  'vande': <gensim.models.keyedvectors.Vocab at 0x1a287c7c88>,
#  'kercke': <gensim.models.keyedvectors.Vocab at 0x1a287c7cc0>,
#  'gades': <gensim.models.keyedvectors.Vocab at 0x1a287c7cf8>,
#  'waer': <gensim.models.keyedvectors.Vocab at 0x1a287c7d30>,
#  'selve': <gensim.models.keyedvectors.Vocab at 0x1a287c7d68>,
#  'nu': <gensim.models.keyedvectors.Vocab at 0x1a287c7da0>,
#  'vinden': <gensim.models.keyedvectors.Vocab at 0x1a287c7dd8>,
#  'ende': <gensim.models.keyedvectors.Vocab at 0x1a287c7e10>,
#  'welcke': <gensim.models.keyedvectors.Vocab at 0x1a287c7e48>,
#  'alleen': <gensim.models.keyedvectors.Vocab at 0x1a287c7e80>,
#  'rechte': <gensim.models.keyedvectors.Vocab at 0x1a287c7eb8>,
#  'daermen': <gensim.models.keyedvectors.Vocab at 0x1a287c7ef0>,
#  'hem': <gensim.models.keyedvectors.Vocab at 0x1a287c7f28>,
#  'behoort': <gensim.models.keyedvectors.Vocab at 0x1a287c7f60>,
#  'voeghen': <gensim.models.keyedvectors.Vocab at 0x1a287c7f98>,
#  'wat': <gensim.models.keyedvectors.Vocab at 0x1a287c7fd0>,
#  'mert': <gensim.models.keyedvectors.Vocab at 0x1a287ca048>,
#  'geloven': <gensim.models.keyedvectors.Vocab at 0x1a287ca080>,
#  'lll': <gensim.models.keyedvectors.Vocab at 0x1a287ca0b8>,
#  'iv': <gensim.models.keyedvectors.Vocab at 0x1a287ca0f0>,
#  'h': <gensim.models.keyedvectors.Vocab at 0x1a287ca128>,
#  'olivier': <gensim.models.keyedvectors.Vocab at 0x1a287ca160>,
#  'fatio': <gensim.models.keyedvectors.Vocab at 0x1a287ca198>,
#  'tude': <gensim.models.keyedvectors.Vocab at 0x1a287ca1d0>,
#  'tablissement': <gensim.models.keyedvectors.Vocab at 0x1a287ca208>,
#  'la': <gensim.models.keyedvectors.Vocab at 0x1a287ca240>,
#  'discipline': <gensim.models.keyedvectors.Vocab at 0x1a287ca278>,
#  'ecc': <gensim.models.keyedvectors.Vocab at 0x1a287ca2b0>,
#  'siaslique': <gensim.models.keyedvectors.Vocab at 0x1a287ca2e8>,
#  'aux': <gensim.models.keyedvectors.Vocab at 0x1a287ca320>,
#  'pays': <gensim.models.keyedvectors.Vocab at 0x1a287ca358>,
#  'bas': <gensim.models.keyedvectors.Vocab at 0x1a287ca390>,
#  'ou': <gensim.models.keyedvectors.Vocab at 0x1a287ca3c8>,
#  'lambert': <gensim.models.keyedvectors.Vocab at 0x1a287ca400>,
#  'leiden': <gensim.models.keyedvectors.Vocab at 0x1a287ca438>,
#  'royaards': <gensim.models.keyedvectors.Vocab at 0x1a287ca470>,
#  'geschiedenis': <gensim.models.keyedvectors.Vocab at 0x1a287ca4a8>,
#  'hervorming': <gensim.models.keyedvectors.Vocab at 0x1a287ca4e0>,
#  'stad': <gensim.models.keyedvectors.Vocab at 0x1a287ca518>,
#  'jan': <gensim.models.keyedvectors.Vocab at 0x1a287ca550>,
#  'wiarda': <gensim.models.keyedvectors.Vocab at 0x1a287ca588>,
#  'huibert': <gensim.models.keyedvectors.Vocab at 0x1a287ca5c0>,
#  'prediker': <gensim.models.keyedvectors.Vocab at 0x1a287ca5f8>,
#  'van': <gensim.models.keyedvectors.Vocab at 0x1a287ca630>,
#  'st': <gensim.models.keyedvectors.Vocab at 0x1a287ca668>,
#  'jacob': <gensim.models.keyedvectors.Vocab at 0x1a287ca6a0>,
#  'amsterdam': <gensim.models.keyedvectors.Vocab at 0x1a287ca6d8>,
#  'voor': <gensim.models.keyedvectors.Vocab at 0x1a287ca710>,
#  'church': <gensim.models.keyedvectors.Vocab at 0x1a287ca748>,
#  's': <gensim.models.keyedvectors.Vocab at 0x1a287ca780>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x1a287ca7b8>,
#  'permissive': <gensim.models.keyedvectors.Vocab at 0x1a287ca7f0>,
#  'past': <gensim.models.keyedvectors.Vocab at 0x1a287ca828>,
#  'its': <gensim.models.keyedvectors.Vocab at 0x1a287ca860>,
#  'tridentine': <gensim.models.keyedvectors.Vocab at 0x1a287ca898>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x1a287ca8d0>,
#  'until': <gensim.models.keyedvectors.Vocab at 0x1a287ca908>,
#  'late': <gensim.models.keyedvectors.Vocab at 0x1a287ca940>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x1a287ca978>,
#  'hoped': <gensim.models.keyedvectors.Vocab at 0x1a287ca9b0>,
#  'reform': <gensim.models.keyedvectors.Vocab at 0x1a287ca9e8>,
#  'within': <gensim.models.keyedvectors.Vocab at 0x1a287caa20>,
#  'spiritualists': <gensim.models.keyedvectors.Vocab at 0x1a287caa58>,
#  'clearly': <gensim.models.keyedvectors.Vocab at 0x1a287caa90>,
#  'shared': <gensim.models.keyedvectors.Vocab at 0x1a287caac8>,
#  'hope': <gensim.models.keyedvectors.Vocab at 0x1a287cab00>,
#  'spiritualism': <gensim.models.keyedvectors.Vocab at 0x1a287cab38>,
#  'surviving': <gensim.models.keyedvectors.Vocab at 0x1a287cab70>,
#  'date': <gensim.models.keyedvectors.Vocab at 0x1a287caba8>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x1a287cabe0>,
#  'break': <gensim.models.keyedvectors.Vocab at 0x1a287cac18>,
#  'catholicism': <gensim.models.keyedvectors.Vocab at 0x1a287cac50>,
#  'between': <gensim.models.keyedvectors.Vocab at 0x1a287cac88>,
#  'june': <gensim.models.keyedvectors.Vocab at 0x1a287cacc0>,
#  'april': <gensim.models.keyedvectors.Vocab at 0x1a287cacf8>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x1a287cad30>,
#  'scholar': <gensim.models.keyedvectors.Vocab at 0x1a287cad68>,
#  'previously': <gensim.models.keyedvectors.Vocab at 0x1a287cada0>,
#  'exa': <gensim.models.keyedvectors.Vocab at 0x1a287cadd8>,
#  'mined': <gensim.models.keyedvectors.Vocab at 0x1a287cae10>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x1a287cae48>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x1a287cae80>,
#  'wrote': <gensim.models.keyedvectors.Vocab at 0x1a287caeb8>,
#  'th': <gensim.models.keyedvectors.Vocab at 0x1a287caef0>,
#  'thesis': <gensim.models.keyedvectors.Vocab at 0x1a287caf28>,
#  'largely': <gensim.models.keyedvectors.Vocab at 0x1a287caf60>,
#  'basis': <gensim.models.keyedvectors.Vocab at 0x1a287caf98>,
#  'concluded': <gensim.models.keyedvectors.Vocab at 0x1a287cafd0>,
#  'eclectic': <gensim.models.keyedvectors.Vocab at 0x1a287ce048>,
#  'dogma': <gensim.models.keyedvectors.Vocab at 0x1a287ce080>,
#  'agreeing': <gensim.models.keyedvectors.Vocab at 0x1a287ce0b8>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x1a287ce0f0>,
#  'reformed': <gensim.models.keyedvectors.Vocab at 0x1a287ce128>,
#  'doctrine': <gensim.models.keyedvectors.Vocab at 0x1a287ce160>,
#  'predestination': <gensim.models.keyedvectors.Vocab at 0x1a287ce198>,
#  'indeed': <gensim.models.keyedvectors.Vocab at 0x1a287ce1d0>,
#  'contain': <gensim.models.keyedvectors.Vocab at 0x1a287ce208>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x1a287ce240>,
#  'passages': <gensim.models.keyedvectors.Vocab at 0x1a287ce278>,
#  'acceptable': <gensim.models.keyedvectors.Vocab at 0x1a287ce2b0>,
#  'transubstantiation': <gensim.models.keyedvectors.Vocab at 0x1a287ce2e8>,
#  'processions': <gensim.models.keyedvectors.Vocab at 0x1a287ce320>,
#  'veneration': <gensim.models.keyedvectors.Vocab at 0x1a287ce358>,
#  'saints': <gensim.models.keyedvectors.Vocab at 0x1a287ce390>,
#  'images': <gensim.models.keyedvectors.Vocab at 0x1a287ce3c8>,
#  'papacy': <gensim.models.keyedvectors.Vocab at 0x1a287ce400>,
#  'bishops': <gensim.models.keyedvectors.Vocab at 0x1a287ce438>,
#  'purgatory': <gensim.models.keyedvectors.Vocab at 0x1a287ce470>,
#  'mendicant': <gensim.models.keyedvectors.Vocab at 0x1a287ce4a8>,
#  'ideal': <gensim.models.keyedvectors.Vocab at 0x1a287ce4e0>,
#  'holiness': <gensim.models.keyedvectors.Vocab at 0x1a287ce518>,
#  'ritual': <gensim.models.keyedvectors.Vocab at 0x1a287ce550>,
#  'confession': <gensim.models.keyedvectors.Vocab at 0x1a287ce588>,
#  'argues': <gensim.models.keyedvectors.Vocab at 0x1a287ce5c0>,
#  'sufficiency': <gensim.models.keyedvectors.Vocab at 0x1a287ce5f8>,
#  'christ': <gensim.models.keyedvectors.Vocab at 0x1a287ce630>,
#  'unique': <gensim.models.keyedvectors.Vocab at 0x1a287ce668>,
#  'sacrifice': <gensim.models.keyedvectors.Vocab at 0x1a287ce6a0>,
#  'role': <gensim.models.keyedvectors.Vocab at 0x1a287ce6d8>,
#  'mediator': <gensim.models.keyedvectors.Vocab at 0x1a287ce710>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x1a287ce748>,
#  'god': <gensim.models.keyedvectors.Vocab at 0x1a287ce780>,
#  'purely': <gensim.models.keyedvectors.Vocab at 0x1a287ce7b8>,
#  'symbolic': <gensim.models.keyedvectors.Vocab at 0x1a287ce7f0>,
#  'un': <gensim.models.keyedvectors.Vocab at 0x1a287ce828>,
#  'derstanding': <gensim.models.keyedvectors.Vocab at 0x1a287ce860>,
#  'eucharist': <gensim.models.keyedvectors.Vocab at 0x1a287ce898>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x1a287ce8d0>,
#  'such': <gensim.models.keyedvectors.Vocab at 0x1a287ce908>,
#  'doctrinal': <gensim.models.keyedvectors.Vocab at 0x1a287ce940>,
#  'points': <gensim.models.keyedvectors.Vocab at 0x1a287ce978>,
#  'missed': <gensim.models.keyedvectors.Vocab at 0x1a287ce9b0>,
#  'essential': <gensim.models.keyedvectors.Vocab at 0x1a287ce9e8>,
#  'thrust': <gensim.models.keyedvectors.Vocab at 0x1a287cea20>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x1a287cea58>,
#  'demonstrate': <gensim.models.keyedvectors.Vocab at 0x1a287cea90>,
#  'con': <gensim.models.keyedvectors.Vocab at 0x1a287ceac8>,
#  'kernel': <gensim.models.keyedvectors.Vocab at 0x1a287ceb00>,
#  'religiosity': <gensim.models.keyedvectors.Vocab at 0x1a287ceb38>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x1a287ceb70>,
#  'stage': <gensim.models.keyedvectors.Vocab at 0x1a287ceba8>,
#  'fore': <gensim.models.keyedvectors.Vocab at 0x1a287cebe0>,
#  'spiritualist': <gensim.models.keyedvectors.Vocab at 0x1a287cec18>,
#  'chief': <gensim.models.keyedvectors.Vocab at 0x1a287cec50>,
#  'source': <gensim.models.keyedvectors.Vocab at 0x1a287cec88>,
#  'mysticism': <gensim.models.keyedvectors.Vocab at 0x1a287cecc0>,
#  'meister': <gensim.models.keyedvectors.Vocab at 0x1a287cecf8>,
#  'eckhardt': <gensim.models.keyedvectors.Vocab at 0x1a287ced30>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x1a287ced68>,
#  'humanist': <gensim.models.keyedvectors.Vocab at 0x1a287ceda0>,
#  'benito': <gensim.models.keyedvectors.Vocab at 0x1a287cedd8>,
#  'arias': <gensim.models.keyedvectors.Vocab at 0x1a287cee10>,
#  'montana': <gensim.models.keyedvectors.Vocab at 0x1a287cee48>,
#  'offers': <gensim.models.keyedvectors.Vocab at 0x1a287cee80>,
#  'extreme': <gensim.models.keyedvectors.Vocab at 0x1a287ceeb8>,
#  'phenomenon': <gensim.models.keyedvectors.Vocab at 0x1a287ceef0>,
#  'rekers': <gensim.models.keyedvectors.Vocab at 0x1a287cef28>,
#  'beni': <gensim.models.keyedvectors.Vocab at 0x1a287cef60>,
#  'london': <gensim.models.keyedvectors.Vocab at 0x1a287cef98>,
#  'hamilton': <gensim.models.keyedvectors.Vocab at 0x1a287cefd0>,
#  'fa': <gensim.models.keyedvectors.Vocab at 0x1a287d2048>,
#  'mily': <gensim.models.keyedvectors.Vocab at 0x1a287d2080>,
#  'aflove': <gensim.models.keyedvectors.Vocab at 0x1a287d20b8>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x1a287d20f0>,
#  'fact': <gensim.models.keyedvectors.Vocab at 0x1a287d2128>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x1a287d2160>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x1a287d2198>,
#  'clarify': <gensim.models.keyedvectors.Vocab at 0x1a287d21d0>,
#  'mystery': <gensim.models.keyedvectors.Vocab at 0x1a287d2208>,
#  'acceptability': <gensim.models.keyedvectors.Vocab at 0x1a287d2240>,
#  'orthodox': <gensim.models.keyedvectors.Vocab at 0x1a287d2278>,
#  'catholics': <gensim.models.keyedvectors.Vocab at 0x1a287d22b0>,
#  'prior': <gensim.models.keyedvectors.Vocab at 0x1a287d22e8>,
#  'arrival': <gensim.models.keyedvectors.Vocab at 0x1a287d2320>,
#  'co': <gensim.models.keyedvectors.Vocab at 0x1a287d2358>,
#  'pastors': <gensim.models.keyedvectors.Vocab at 0x1a287d2390>,
#  'jacobskerk': <gensim.models.keyedvectors.Vocab at 0x1a287d23c8>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x1a287d2400>,
#  'frans': <gensim.models.keyedvectors.Vocab at 0x1a287d2438>,
#  'est': <gensim.models.keyedvectors.Vocab at 0x1a287d2470>,
#  'johan': <gensim.models.keyedvectors.Vocab at 0x1a287d24a8>,
#  'haller': <gensim.models.keyedvectors.Vocab at 0x1a287d24e0>,
#  'seems': <gensim.models.keyedvectors.Vocab at 0x1a287d2518>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x1a287d2550>,
#  'senior': <gensim.models.keyedvectors.Vocab at 0x1a287d2588>,
#  'annual': <gensim.models.keyedvectors.Vocab at 0x1a287d25c0>,
#  'lenten': <gensim.models.keyedvectors.Vocab at 0x1a287d25f8>,
#  'series': <gensim.models.keyedvectors.Vocab at 0x1a287d2630>,
#  'ser': <gensim.models.keyedvectors.Vocab at 0x1a287d2668>,
#  'mons': <gensim.models.keyedvectors.Vocab at 0x1a287d26a0>,
#  'passion': <gensim.models.keyedvectors.Vocab at 0x1a287d26d8>,
#  'served': <gensim.models.keyedvectors.Vocab at 0x1a287d2710>,
#  'pastor': <gensim.models.keyedvectors.Vocab at 0x1a287d2748>,
#  'notary': <gensim.models.keyedvectors.Vocab at 0x1a287d2780>,
#  'stripped': <gensim.models.keyedvectors.Vocab at 0x1a287d27b8>,
#  'pastorate': <gensim.models.keyedvectors.Vocab at 0x1a287d27f0>,
#  'effect': <gensim.models.keyedvectors.Vocab at 0x1a287d2828>,
#  'replaced': <gensim.models.keyedvectors.Vocab at 0x1a287d2860>,
#  'vicar': <gensim.models.keyedvectors.Vocab at 0x1a287d2898>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x1a287d28d0>,
#  'usual': <gensim.models.keyedvectors.Vocab at 0x1a287d2908>,
#  'move': <gensim.models.keyedvectors.Vocab at 0x1a287d2940>,
#  'clue': <gensim.models.keyedvectors.Vocab at 0x1a287d2978>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x1a287d29b0>,
#  'explaining': <gensim.models.keyedvectors.Vocab at 0x1a287d29e8>,
#  'comes': <gensim.models.keyedvectors.Vocab at 0x1a287d2a20>,
#  'list': <gensim.models.keyedvectors.Vocab at 0x1a287d2a58>,
#  'persons': <gensim.models.keyedvectors.Vocab at 0x1a287d2a90>,
#  'admitted': <gensim.models.keyedvectors.Vocab at 0x1a287d2ac8>,
#  'communion': <gensim.models.keyedvectors.Vocab at 0x1a287d2b00>,
#  'starting': <gensim.models.keyedvectors.Vocab at 0x1a287d2b38>,
#  'received': <gensim.models.keyedvectors.Vocab at 0x1a287d2b70>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x1a287d2ba8>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x1a287d2be0>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x1a287d2c18>,
#  'christmas': <gensim.models.keyedvectors.Vocab at 0x1a287d2c50>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x1a287d2c88>,
#  'opportunity': <gensim.models.keyedvectors.Vocab at 0x1a287d2cc0>,
#  'respectable': <gensim.models.keyedvectors.Vocab at 0x1a287d2cf8>,
#  'death': <gensim.models.keyedvectors.Vocab at 0x1a287d2d30>,
#  'duif': <gensim.models.keyedvectors.Vocab at 0x1a287d2d68>,
#  'huis': <gensim.models.keyedvectors.Vocab at 0x1a287d2da0>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x1a287d2dd8>,
#  'timing': <gensim.models.keyedvectors.Vocab at 0x1a287d2e10>,
#  'suggests': <gensim.models.keyedvectors.Vocab at 0x1a287d2e48>,
#  'perhaps': <gensim.models.keyedvectors.Vocab at 0x1a287d2e80>,
#  'supporter': <gensim.models.keyedvectors.Vocab at 0x1a287d2eb8>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x1a287d2ef0>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x1a287d2f28>,
#  'considerably': <gensim.models.keyedvectors.Vocab at 0x1a287d2f60>,
#  'sympathetic': <gensim.models.keyedvectors.Vocab at 0x1a287d2f98>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x1a287d2fd0>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x1a287d5048>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x1a287d5080>,
#  'longer': <gensim.models.keyedvectors.Vocab at 0x1a287d50b8>,
#  'u': <gensim.models.keyedvectors.Vocab at 0x1a287d50f0>,
#  'fo': <gensim.models.keyedvectors.Vocab at 0x1a287d5128>,
#  'r': <gensim.models.keyedvectors.Vocab at 0x1a287d5160>,
#  'waarde': <gensim.models.keyedvectors.Vocab at 0x1a287d5198>,
#  'archieven': <gensim.models.keyedvectors.Vocab at 0x1a287d51d0>,
#  'kerkeraad': <gensim.models.keyedvectors.Vocab at 0x1a287d5208>,
#  'nederlandse': <gensim.models.keyedvectors.Vocab at 0x1a287d5240>,
#  'hervormde': <gensim.models.keyedvectors.Vocab at 0x1a287d5278>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x1a287d52b0>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x1a287d52e8>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x1a287d5320>,
#  'collection': <gensim.models.keyedvectors.Vocab at 0x1a287d5358>,
#  'remonstrantse': <gensim.models.keyedvectors.Vocab at 0x1a287d5390>,
#  'housed': <gensim.models.keyedvectors.Vocab at 0x1a287d53c8>,
#  'rotter': <gensim.models.keyedvectors.Vocab at 0x1a287d5400>,
#  'dam': <gensim.models.keyedvectors.Vocab at 0x1a287d5438>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x1a287d5470>,
#  'handschrift': <gensim.models.keyedvectors.Vocab at 0x1a287d54a8>,
#  'entitled': <gensim.models.keyedvectors.Vocab at 0x1a287d54e0>,
#  'sermoenen': <gensim.models.keyedvectors.Vocab at 0x1a287d5518>,
#  'saliger': <gensim.models.keyedvectors.Vocab at 0x1a287d5550>,
#  'heer': <gensim.models.keyedvectors.Vocab at 0x1a287d5588>,
#  'contains': <gensim.models.keyedvectors.Vocab at 0x1a287d55c0>,
#  'following': <gensim.models.keyedvectors.Vocab at 0x1a287d55f8>,
#  'lst': <gensim.models.keyedvectors.Vocab at 0x1a287d5630>,
#  'sermon': <gensim.models.keyedvectors.Vocab at 0x1a287d5668>,
#  'luke': <gensim.models.keyedvectors.Vocab at 0x1a287d56a0>,
#  'nd': <gensim.models.keyedvectors.Vocab at 0x1a287d56d8>,
#  'en': <gensim.models.keyedvectors.Vocab at 0x1a287d5710>,
#  'stephan': <gensim.models.keyedvectors.Vocab at 0x1a287d5748>,
#  'acts': <gensim.models.keyedvectors.Vocab at 0x1a287d5780>,
#  'extract': <gensim.models.keyedvectors.Vocab at 0x1a287d57b8>,
#  'matth': <gensim.models.keyedvectors.Vocab at 0x1a287d57f0>,
#  'easter': <gensim.models.keyedvectors.Vocab at 0x1a287d5828>,
#  'mark': <gensim.models.keyedvectors.Vocab at 0x1a287d5860>,
#  'ends': <gensim.models.keyedvectors.Vocab at 0x1a287d5898>,
#  'mid': <gensim.models.keyedvectors.Vocab at 0x1a287d58d0>,
#  'sentence': <gensim.models.keyedvectors.Vocab at 0x1a287d5908>,
#  'v': <gensim.models.keyedvectors.Vocab at 0x1a287d5940>,
#  'historie': <gensim.models.keyedvectors.Vocab at 0x1a287d5978>,
#  't': <gensim.models.keyedvectors.Vocab at 0x1a287d59b0>,
#  'onses': <gensim.models.keyedvectors.Vocab at 0x1a287d59e8>,
#  'makers': <gensim.models.keyedvectors.Vocab at 0x1a287d5a20>,
#  'jesu': <gensim.models.keyedvectors.Vocab at 0x1a287d5a58>,
#  'christi': <gensim.models.keyedvectors.Vocab at 0x1a287d5a90>,
#  'uijt': <gensim.models.keyedvectors.Vocab at 0x1a287d5ac8>,
#  'vier': <gensim.models.keyedvectors.Vocab at 0x1a287d5b00>,
#  'samen': <gensim.models.keyedvectors.Vocab at 0x1a287d5b38>,
#  'verklaringe': <gensim.models.keyedvectors.Vocab at 0x1a287d5b70>,
#  'daar': <gensim.models.keyedvectors.Vocab at 0x1a287d5ba8>,
#  'over': <gensim.models.keyedvectors.Vocab at 0x1a287d5be0>,
#  'gedaan': <gensim.models.keyedvectors.Vocab at 0x1a287d5c18>,
#  'afgedeelt': <gensim.models.keyedvectors.Vocab at 0x1a287d5c50>,
#  'lt': <gensim.models.keyedvectors.Vocab at 0x1a287d5c88>,
#  'fourteen': <gensim.models.keyedvectors.Vocab at 0x1a287d5cc0>,
#  'included': <gensim.models.keyedvectors.Vocab at 0x1a287d5cf8>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x1a287d5d30>,
#  'numerous': <gensim.models.keyedvectors.Vocab at 0x1a287d5d68>,
#  'often': <gensim.models.keyedvectors.Vocab at 0x1a287d5da0>,
#  'extensive': <gensim.models.keyedvectors.Vocab at 0x1a287d5dd8>,
#  'manuscripts': <gensim.models.keyedvectors.Vocab at 0x1a287d5e10>,
#  'then': <gensim.models.keyedvectors.Vocab at 0x1a287d5e48>,
#  'gratefully': <gensim.models.keyedvectors.Vocab at 0x1a287d5e80>,
#  'drawn': <gensim.models.keyedvectors.Vocab at 0x1a287d5eb8>,
#  'third': <gensim.models.keyedvectors.Vocab at 0x1a287d5ef0>,
#  'manuscript': <gensim.models.keyedvectors.Vocab at 0x1a287d5f28>,
#  'known': <gensim.models.keyedvectors.Vocab at 0x1a287d5f60>,
#  'utrechtse': <gensim.models.keyedvectors.Vocab at 0x1a287d5f98>,
#  'single': <gensim.models.keyedvectors.Vocab at 0x1a287d5fd0>,
#  'sermoen': <gensim.models.keyedvectors.Vocab at 0x1a287d9048>,
#  'op': <gensim.models.keyedvectors.Vocab at 0x1a287d9080>,
#  'gedaen': <gensim.models.keyedvectors.Vocab at 0x1a287d90b8>,
#  'door': <gensim.models.keyedvectors.Vocab at 0x1a287d90f0>,
#  'pater': <gensim.models.keyedvectors.Vocab at 0x1a287d9128>,
#  'predicant': <gensim.models.keyedvectors.Vocab at 0x1a287d9160>,
#  'jacobs': <gensim.models.keyedvectors.Vocab at 0x1a287d9198>,
#  'kerck': <gensim.models.keyedvectors.Vocab at 0x1a287d91d0>,
#  'tot': <gensim.models.keyedvectors.Vocab at 0x1a287d9208>,
#  'dui': <gensim.models.keyedvectors.Vocab at 0x1a287d9240>,
#  'gaat': <gensim.models.keyedvectors.Vocab at 0x1a287d9278>,
#  'het': <gensim.models.keyedvectors.Vocab at 0x1a287d92b0>,
#  'koloniale': <gensim.models.keyedvectors.Vocab at 0x1a287d92e8>,
#  'mexico': <gensim.models.keyedvectors.Vocab at 0x1a287d9320>,
#  'spaanse': <gensim.models.keyedvectors.Vocab at 0x1a287d9358>,
#  'wereldrijk': <gensim.models.keyedvectors.Vocab at 0x1a287d9390>,
#  'europese': <gensim.models.keyedvectors.Vocab at 0x1a287d93c8>,
#  'jodendom': <gensim.models.keyedvectors.Vocab at 0x1a287d9400>,
#  'hol': <gensim.models.keyedvectors.Vocab at 0x1a287d9438>,
#  'landse': <gensim.models.keyedvectors.Vocab at 0x1a287d9470>,
#  'handelssysteem': <gensim.models.keyedvectors.Vocab at 0x1a287d94a8>,
#  'telkens': <gensim.models.keyedvectors.Vocab at 0x1a287d94e0>,
#  'wordt': <gensim.models.keyedvectors.Vocab at 0x1a287d9518>,
#  'men': <gensim.models.keyedvectors.Vocab at 0x1a287d9550>,
#  'ge': <gensim.models.keyedvectors.Vocab at 0x1a287d9588>,
#  'mponeerd': <gensim.models.keyedvectors.Vocab at 0x1a287d95c0>,
#  'enorme': <gensim.models.keyedvectors.Vocab at 0x1a287d95f8>,
#  'talenkennis': <gensim.models.keyedvectors.Vocab at 0x1a287d9630>,
#  'erudi': <gensim.models.keyedvectors.Vocab at 0x1a287d9668>,
#  'tie': <gensim.models.keyedvectors.Vocab at 0x1a287d96a0>,
#  'archiefstudie': <gensim.models.keyedvectors.Vocab at 0x1a287d96d8>,
#  'accuratesse': <gensim.models.keyedvectors.Vocab at 0x1a287d9710>,
#  'originaliteit': <gensim.models.keyedvectors.Vocab at 0x1a287d9748>,
#  'auteur': <gensim.models.keyedvectors.Vocab at 0x1a287d9780>,
#  'die': <gensim.models.keyedvectors.Vocab at 0x1a287d97b8>,
#  'nimmer': <gensim.models.keyedvectors.Vocab at 0x1a287d97f0>,
#  'platgetreden': <gensim.models.keyedvectors.Vocab at 0x1a287d9828>,
#  'paden': <gensim.models.keyedvectors.Vocab at 0x1a287d9860>,
#  'volgt': <gensim.models.keyedvectors.Vocab at 0x1a287d9898>,
#  'deze': <gensim.models.keyedvectors.Vocab at 0x1a287d98d0>,
#  'wijze': <gensim.models.keyedvectors.Vocab at 0x1a287d9908>,
#  'hij': <gensim.models.keyedvectors.Vocab at 0x1a287d9940>,
#  'ongemerkt': <gensim.models.keyedvectors.Vocab at 0x1a287d9978>,
#  'bezig': <gensim.models.keyedvectors.Vocab at 0x1a287d99b0>,
#  'grensgebied': <gensim.models.keyedvectors.Vocab at 0x1a287d99e8>,
#  'tussen': <gensim.models.keyedvectors.Vocab at 0x1a287d9a20>,
#  'politieke': <gensim.models.keyedvectors.Vocab at 0x1a287d9a58>,
#  'econo': <gensim.models.keyedvectors.Vocab at 0x1a287d9a90>,
#  'mische': <gensim.models.keyedvectors.Vocab at 0x1a287d9ac8>,
#  'geschiedschrijving': <gensim.models.keyedvectors.Vocab at 0x1a287d9b00>,
#  'onontgonnen': <gensim.models.keyedvectors.Vocab at 0x1a287d9b38>,
#  'terrein': <gensim.models.keyedvectors.Vocab at 0x1a287d9b70>,
#  'eigen': <gensim.models.keyedvectors.Vocab at 0x1a287d9ba8>,
#  'wereld': <gensim.models.keyedvectors.Vocab at 0x1a287d9be0>,
#  'cre': <gensim.models.keyedvectors.Vocab at 0x1a287d9c18>,
#  'ren': <gensim.models.keyedvectors.Vocab at 0x1a287d9c50>,
#  'zonder': <gensim.models.keyedvectors.Vocab at 0x1a287d9c88>,
#  'zich': <gensim.models.keyedvectors.Vocab at 0x1a287d9cc0>,
#  'veel': <gensim.models.keyedvectors.Vocab at 0x1a287d9cf8>,
#  'aan': <gensim.models.keyedvectors.Vocab at 0x1a287d9d30>,
#  'trekken': <gensim.models.keyedvectors.Vocab at 0x1a287d9d68>,
#  'kritiek': <gensim.models.keyedvectors.Vocab at 0x1a287d9da0>,
#  'zijn': <gensim.models.keyedvectors.Vocab at 0x1a287d9dd8>,
#  'voorstellingen': <gensim.models.keyedvectors.Vocab at 0x1a287d9e10>,
#  'uitgeoefend': <gensim.models.keyedvectors.Vocab at 0x1a287d9e48>,
#  'niemand': <gensim.models.keyedvectors.Vocab at 0x1a287d9e80>,
#  'heeft': <gensim.models.keyedvectors.Vocab at 0x1a287d9eb8>,
#  'laatste': <gensim.models.keyedvectors.Vocab at 0x1a287d9ef0>,
#  'decennium': <gensim.models.keyedvectors.Vocab at 0x1a287d9f28>,
#  'meer': <gensim.models.keyedvectors.Vocab at 0x1a287d9f60>,
#  'om': <gensim.models.keyedvectors.Vocab at 0x1a287d9f98>,
#  'republiek': <gensim.models.keyedvectors.Vocab at 0x1a287d9fd0>,
#  'centrum': <gensim.models.keyedvectors.Vocab at 0x1a287dc048>,
#  'internatio': <gensim.models.keyedvectors.Vocab at 0x1a287dc080>,
#  'nale': <gensim.models.keyedvectors.Vocab at 0x1a287dc0b8>,
#  'belangstelling': <gensim.models.keyedvectors.Vocab at 0x1a287dc0f0>,
#  'plaatsen': <gensim.models.keyedvectors.Vocab at 0x1a287dc128>,
#  'niet': <gensim.models.keyedvectors.Vocab at 0x1a287dc160>,
#  'met': <gensim.models.keyedvectors.Vocab at 0x1a287dc198>,
#  'boeken': <gensim.models.keyedvectors.Vocab at 0x1a287dc1d0>,
#  'ook': <gensim.models.keyedvectors.Vocab at 0x1a287dc208>,
#  'artikelen': <gensim.models.keyedvectors.Vocab at 0x1a287dc240>,
#  'drijven': <gensim.models.keyedvectors.Vocab at 0x1a287dc278>,
#  'israel': <gensim.models.keyedvectors.Vocab at 0x1a287dc2b0>,
#  'kans': <gensim.models.keyedvectors.Vocab at 0x1a287dc2e8>,
#  'gezien': <gensim.models.keyedvectors.Vocab at 0x1a287dc320>,
#  'tientallen': <gensim.models.keyedvectors.Vocab at 0x1a287dc358>,
#  'belangrijke': <gensim.models.keyedvectors.Vocab at 0x1a287dc390>,
#  'korte': <gensim.models.keyedvectors.Vocab at 0x1a287dc3c8>,
#  'studies': <gensim.models.keyedvectors.Vocab at 0x1a287dc400>,
#  'schrijven': <gensim.models.keyedvectors.Vocab at 0x1a287dc438>,
#  'slechts': <gensim.models.keyedvectors.Vocab at 0x1a287dc470>,
#  'ten': <gensim.models.keyedvectors.Vocab at 0x1a287dc4a8>,
#  'dele': <gensim.models.keyedvectors.Vocab at 0x1a287dc4e0>,
#  'verwerkt': <gensim.models.keyedvectors.Vocab at 0x1a287dc518>,
#  'voornaamste': <gensim.models.keyedvectors.Vocab at 0x1a287dc550>,
#  'gebundeld': <gensim.models.keyedvectors.Vocab at 0x1a287dc588>,
#  'aangevuld': <gensim.models.keyedvectors.Vocab at 0x1a287dc5c0>,
#  'mirabile': <gensim.models.keyedvectors.Vocab at 0x1a287dc5f8>,
#  'diclu': <gensim.models.keyedvectors.Vocab at 0x1a287dc630>,
#  'drie': <gensim.models.keyedvectors.Vocab at 0x1a287dc668>,
#  'nieuwe': <gensim.models.keyedvectors.Vocab at 0x1a287dc6a0>,
#  'bijdragen': <gensim.models.keyedvectors.Vocab at 0x1a287dc6d8>,
#  'eerste': <gensim.models.keyedvectors.Vocab at 0x1a287dc710>,
#  'aandacht': <gensim.models.keyedvectors.Vocab at 0x1a287dc748>,
#  'trokken': <gensim.models.keyedvectors.Vocab at 0x1a287dc780>,
#  'waren': <gensim.models.keyedvectors.Vocab at 0x1a287dc7b8>,
#  'conflict': <gensim.models.keyedvectors.Vocab at 0x1a287dc7f0>,
#  'pires': <gensim.models.keyedvectors.Vocab at 0x1a287dc828>,
#  'spain': <gensim.models.keyedvectors.Vocab at 0x1a287dc860>,
#  'towns': <gensim.models.keyedvectors.Vocab at 0x1a287dc898>,
#  'spanish': <gensim.models.keyedvectors.Vocab at 0x1a287dc8d0>,
#  'ict': <gensim.models.keyedvectors.Vocab at 0x1a287dc908>,
#  'tegen': <gensim.models.keyedvectors.Vocab at 0x1a287dc940>,
#  'ganse': <gensim.models.keyedvectors.Vocab at 0x1a287dc978>,
#  'historiografische': <gensim.models.keyedvectors.Vocab at 0x1a287dc9b0>,
#  'traditie': <gensim.models.keyedvectors.Vocab at 0x1a287dc9e8>,
#  'beklem': <gensim.models.keyedvectors.Vocab at 0x1a287dca20>,
#  'toont': <gensim.models.keyedvectors.Vocab at 0x1a287dca58>,
#  'hi': <gensim.models.keyedvectors.Vocab at 0x1a287dca90>,
#  'daarin': <gensim.models.keyedvectors.Vocab at 0x1a287dcac8>,
#  'dat': <gensim.models.keyedvectors.Vocab at 0x1a287dcb00>,
#  'rijk': <gensim.models.keyedvectors.Vocab at 0x1a287dcb38>,
#  'na': <gensim.models.keyedvectors.Vocab at 0x1a287dcb70>,
#  'bestand': <gensim.models.keyedvectors.Vocab at 0x1a287dcba8>,
#  'vooral': <gensim.models.keyedvectors.Vocab at 0x1a287dcbe0>,
#  'concentreerde': <gensim.models.keyedvectors.Vocab at 0x1a287dcc18>,
#  'oorlogvoering': <gensim.models.keyedvectors.Vocab at 0x1a287dcc50>,
#  'hollandse': <gensim.models.keyedvectors.Vocab at 0x1a287dcc88>,
#  'steden': <gensim.models.keyedvectors.Vocab at 0x1a287dccc0>,
#  'uiteenlopende': <gensim.models.keyedvectors.Vocab at 0x1a287dccf8>,
#  'economische': <gensim.models.keyedvectors.Vocab at 0x1a287dcd30>,
#  'religieuze': <gensim.models.keyedvectors.Vocab at 0x1a287dcd68>,
#  'belangen': <gensim.models.keyedvectors.Vocab at 0x1a287dcda0>,
#  'omstreeks': <gensim.models.keyedvectors.Vocab at 0x1a287dcdd8>,
#  'hopeloos': <gensim.models.keyedvectors.Vocab at 0x1a287dce10>,
#  'verdeeld': <gensim.models.keyedvectors.Vocab at 0x1a287dce48>,
#  'vraag': <gensim.models.keyedvectors.Vocab at 0x1a287dce80>,
#  'oorlog': <gensim.models.keyedvectors.Vocab at 0x1a287dceb8>,
#  'vrede': <gensim.models.keyedvectors.Vocab at 0x1a287dcef0>,
#  'nog': <gensim.models.keyedvectors.Vocab at 0x1a287dcf28>,
#  'steeds': <gensim.models.keyedvectors.Vocab at 0x1a287dcf60>,
#  'acht': <gensim.models.keyedvectors.Vocab at 0x1a287dcf98>,
#  'ik': <gensim.models.keyedvectors.Vocab at 0x1a287dcfd0>,
#  'twee': <gensim.models.keyedvectors.Vocab at 0x1a287e0048>,
#  'meesterlijke': <gensim.models.keyedvectors.Vocab at 0x1a287e0080>,
#  'beste': <gensim.models.keyedvectors.Vocab at 0x1a287e00b8>,
#  'ooit': <gensim.models.keyedvectors.Vocab at 0x1a287e00f0>,
#  'geschreven': <gensim.models.keyedvectors.Vocab at 0x1a287e0128>,
#  'fraaie': <gensim.models.keyedvectors.Vocab at 0x1a287e0160>,
#  'vorm': <gensim.models.keyedvectors.Vocab at 0x1a287e0198>,
#  'geprononceerde': <gensim.models.keyedvectors.Vocab at 0x1a287e01d0>,
#  'stellingname': <gensim.models.keyedvectors.Vocab at 0x1a287e0208>,
#  'verdienen': <gensim.models.keyedvectors.Vocab at 0x1a287e0240>,
#  'zij': <gensim.models.keyedvectors.Vocab at 0x1a287e0278>,
#  'voorkeur': <gensim.models.keyedvectors.Vocab at 0x1a287e02b0>,
#  'boven': <gensim.models.keyedvectors.Vocab at 0x1a287e02e8>,
#  'betreffende': <gensim.models.keyedvectors.Vocab at 0x1a287e0320>,
#  'gedeelten': <gensim.models.keyedvectors.Vocab at 0x1a287e0358>,
#  'hispanic': <gensim.models.keyedvectors.Vocab at 0x1a287e0390>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x1a287e03c8>,
#  'oxford': <gensim.models.keyedvectors.Vocab at 0x1a287e0400>,
#  'terecht': <gensim.models.keyedvectors.Vocab at 0x1a287e0438>,
#  'nemen': <gensim.models.keyedvectors.Vocab at 0x1a287e0470>,
#  'bundel': <gensim.models.keyedvectors.Vocab at 0x1a287e04a8>,
#  'ereplaats': <gensim.models.keyedvectors.Vocab at 0x1a287e04e0>,
#  'volgende': <gensim.models.keyedvectors.Vocab at 0x1a287e0518>,
#  'hebben': <gensim.models.keyedvectors.Vocab at 0x1a287e0550>,
#  'eveneens': <gensim.models.keyedvectors.Vocab at 0x1a287e0588>,
#  'betrekking': <gensim.models.keyedvectors.Vocab at 0x1a287e05c0>,
#  'phases': <gensim.models.keyedvectors.Vocab at 0x1a287e05f8>,
#  'ritme': <gensim.models.keyedvectors.Vocab at 0x1a287e0630>,
#  'handel': <gensim.models.keyedvectors.Vocab at 0x1a287e0668>,
#  'middellandse': <gensim.models.keyedvectors.Vocab at 0x1a287e06a0>,
#  'zeegebied': <gensim.models.keyedvectors.Vocab at 0x1a287e06d8>,
#  'vijf': <gensim.models.keyedvectors.Vocab at 0x1a287e0710>,
#  'fasen': <gensim.models.keyedvectors.Vocab at 0x1a287e0748>,
#  'waarschijnlijk': <gensim.models.keyedvectors.Vocab at 0x1a287e0780>,
#  'studie': <gensim.models.keyedvectors.Vocab at 0x1a287e07b8>,
#  'bijgedragen': <gensim.models.keyedvectors.Vocab at 0x1a287e07f0>,
#  'strakke': <gensim.models.keyedvectors.Vocab at 0x1a287e0828>,
#  'keurslijf': <gensim.models.keyedvectors.Vocab at 0x1a287e0860>,
#  'waarin': <gensim.models.keyedvectors.Vocab at 0x1a287e0898>,
#  'hele': <gensim.models.keyedvectors.Vocab at 0x1a287e08d0>,
#  'opkomst': <gensim.models.keyedvectors.Vocab at 0x1a287e0908>,
#  'neergang': <gensim.models.keyedvectors.Vocab at 0x1a287e0940>,
#  'wereldhandel': <gensim.models.keyedvectors.Vocab at 0x1a287e0978>,
#  'primacy': <gensim.models.keyedvectors.Vocab at 0x1a287e09b0>,
#  'tra': <gensim.models.keyedvectors.Vocab at 0x1a287e09e8>,
#  'geperst': <gensim.models.keyedvectors.Vocab at 0x1a287e0a20>,
#  'totale': <gensim.models.keyedvectors.Vocab at 0x1a287e0a58>,
#  'zeer': <gensim.models.keyedvectors.Vocab at 0x1a287e0a90>,
#  'dubieus': <gensim.models.keyedvectors.Vocab at 0x1a287e0ac8>,
#  'lijkt': <gensim.models.keyedvectors.Vocab at 0x1a287e0b00>,
#  'mij': <gensim.models.keyedvectors.Vocab at 0x1a287e0b38>,
#  'straatvaart': <gensim.models.keyedvectors.Vocab at 0x1a287e0b70>,
#  'alleszins': <gensim.models.keyedvectors.Vocab at 0x1a287e0ba8>,
#  'aanvaardbaar': <gensim.models.keyedvectors.Vocab at 0x1a287e0be0>,
#  'saaie': <gensim.models.keyedvectors.Vocab at 0x1a287e0c18>,
#  'states': <gensim.models.keyedvectors.Vocab at 0x1a287e0c50>,
#  'neral': <gensim.models.keyedvectors.Vocab at 0x1a287e0c88>,
#  'strategic': <gensim.models.keyedvectors.Vocab at 0x1a287e0cc0>,
#  'regulation': <gensim.models.keyedvectors.Vocab at 0x1a287e0cf8>,
#  'river': <gensim.models.keyedvectors.Vocab at 0x1a287e0d30>,
#  'trade': <gensim.models.keyedvectors.Vocab at 0x1a287e0d68>,
#  'regule': <gensim.models.keyedvectors.Vocab at 0x1a287e0da0>,
#  'ring': <gensim.models.keyedvectors.Vocab at 0x1a287e0dd8>,
#  'rivierhandel': <gensim.models.keyedvectors.Vocab at 0x1a287e0e10>,
#  'toevoer': <gensim.models.keyedvectors.Vocab at 0x1a287e0e48>,
#  'naar': <gensim.models.keyedvectors.Vocab at 0x1a287e0e80>,
#  'vijandelijke': <gensim.models.keyedvectors.Vocab at 0x1a287e0eb8>,
#  'legers': <gensim.models.keyedvectors.Vocab at 0x1a287e0ef0>,
#  'af': <gensim.models.keyedvectors.Vocab at 0x1a287e0f28>,
#  'snijden': <gensim.models.keyedvectors.Vocab at 0x1a287e0f60>,
#  'welko': <gensim.models.keyedvectors.Vocab at 0x1a287e0f98>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x1a287e0fd0>,
#  'aanvulling': <gensim.models.keyedvectors.Vocab at 0x1a287e3048>,
#  'durch': <gensim.models.keyedvectors.Vocab at 0x1a287e3080>,
#  'landen': <gensim.models.keyedvectors.Vocab at 0x1a287e30b8>,
#  'rondom': <gensim.models.keyedvectors.Vocab at 0x1a287e30f0>,
#  'bijna': <gensim.models.keyedvectors.Vocab at 0x1a287e3128>,
#  'geheel': <gensim.models.keyedvectors.Vocab at 0x1a287e3160>,
#  'buiten': <gensim.models.keyedvectors.Vocab at 0x1a287e3198>,
#  'beschouwing': <gensim.models.keyedvectors.Vocab at 0x1a287e31d0>,
#  'laat': <gensim.models.keyedvectors.Vocab at 0x1a287e3208>,
#  'vrij': <gensim.models.keyedvectors.Vocab at 0x1a287e3240>,
#  'teleurstellend': <gensim.models.keyedvectors.Vocab at 0x1a287e3278>,
#  'frederick': <gensim.models.keyedvectors.Vocab at 0x1a287e32b0>,
#  'henry': <gensim.models.keyedvectors.Vocab at 0x1a287e32e8>,
#  'political': <gensim.models.keyedvectors.Vocab at 0x1a287e3320>,
#  'factions': <gensim.models.keyedvectors.Vocab at 0x1a287e3358>,
#  'oppervlakte': <gensim.models.keyedvectors.Vocab at 0x1a287e3390>,
#  'blijft': <gensim.models.keyedvectors.Vocab at 0x1a287e33c8>,
#  'echt': <gensim.models.keyedvectors.Vocab at 0x1a287e3400>,
#  'doordringt': <gensim.models.keyedvectors.Vocab at 0x1a287e3438>,
#  'sche': <gensim.models.keyedvectors.Vocab at 0x1a287e3470>,
#  'persoonlijkheid': <gensim.models.keyedvectors.Vocab at 0x1a287e34a8>,
#  'algemeen': <gensim.models.keyedvectors.Vocab at 0x1a287e34e0>,
#  'trouwens': <gensim.models.keyedvectors.Vocab at 0x1a287e3518>,
#  'affiniteit': <gensim.models.keyedvectors.Vocab at 0x1a287e3550>,
#  'harde': <gensim.models.keyedvectors.Vocab at 0x1a287e3588>,
#  'economi': <gensim.models.keyedvectors.Vocab at 0x1a287e35c0>,
#  'krachten': <gensim.models.keyedvectors.Vocab at 0x1a287e35f8>,
#  'geesteswereld': <gensim.models.keyedvectors.Vocab at 0x1a287e3630>,
#  'vroeger': <gensim.models.keyedvectors.Vocab at 0x1a287e3668>,
#  'eeuwen': <gensim.models.keyedvectors.Vocab at 0x1a287e36a0>,
#  'psyche': <gensim.models.keyedvectors.Vocab at 0x1a287e36d8>,
#  'historische': <gensim.models.keyedvectors.Vocab at 0x1a287e3710>,
#  'figuren': <gensim.models.keyedvectors.Vocab at 0x1a287e3748>,
#  'blijven': <gensim.models.keyedvectors.Vocab at 0x1a287e3780>,
#  'gesloten': <gensim.models.keyedvectors.Vocab at 0x1a287e37b8>,
#  'boek': <gensim.models.keyedvectors.Vocab at 0x1a287e37f0>,
#  'derde': <gensim.models.keyedvectors.Vocab at 0x1a287e3828>,
#  'blok': <gensim.models.keyedvectors.Vocab at 0x1a287e3860>,
#  'daartoe': <gensim.models.keyedvectors.Vocab at 0x1a287e3898>,
#  'behoren': <gensim.models.keyedvectors.Vocab at 0x1a287e38d0>,
#  'teressante': <gensim.models.keyedvectors.Vocab at 0x1a287e3908>,
#  'olivares': <gensim.models.keyedvectors.Vocab at 0x1a287e3940>,
#  'government': <gensim.models.keyedvectors.Vocab at 0x1a287e3978>,
#  'nether': <gensim.models.keyedvectors.Vocab at 0x1a287e39b0>,
#  'lands': <gensim.models.keyedvectors.Vocab at 0x1a287e39e8>,
#  'breuk': <gensim.models.keyedvectors.Vocab at 0x1a287e3a20>,
#  'militaire': <gensim.models.keyedvectors.Vocab at 0x1a287e3a58>,
#  'bestuurlijke': <gensim.models.keyedvectors.Vocab at 0x1a287e3a90>,
#  'ontwikkeling': <gensim.models.keyedvectors.Vocab at 0x1a287e3ac8>,
#  'rond': <gensim.models.keyedvectors.Vocab at 0x1a287e3b00>,
#  'signaleert': <gensim.models.keyedvectors.Vocab at 0x1a287e3b38>,
#  'tweede': <gensim.models.keyedvectors.Vocab at 0x1a287e3b70>,
#  'embargoes': <gensim.models.keyedvectors.Vocab at 0x1a287e3ba8>,
#  'struggle': <gensim.models.keyedvectors.Vocab at 0x1a287e3be0>,
#  'mastery': <gensim.models.keyedvectors.Vocab at 0x1a287e3c18>,
#  'opzichten': <gensim.models.keyedvectors.Vocab at 0x1a287e3c50>,
#  'sleutelhoofdstuk': <gensim.models.keyedvectors.Vocab at 0x1a287e3c88>,
#  'vormt': <gensim.models.keyedvectors.Vocab at 0x1a287e3cc0>,
#  'tracht': <gensim.models.keyedvectors.Vocab at 0x1a287e3cf8>,
#  'hierin': <gensim.models.keyedvectors.Vocab at 0x1a287e3d30>,
#  'vindingrijk': <gensim.models.keyedvectors.Vocab at 0x1a287e3d68>,
#  'vele': <gensim.models.keyedvectors.Vocab at 0x1a287e3da0>,
#  'kanten': <gensim.models.keyedvectors.Vocab at 0x1a287e3dd8>,
#  'gelanceerde': <gensim.models.keyedvectors.Vocab at 0x1a287e3e10>,
#  'weerleggen': <gensim.models.keyedvectors.Vocab at 0x1a287e3e48>,
#  'embargo': <gensim.models.keyedvectors.Vocab at 0x1a287e3e80>,
#  'zeker': <gensim.models.keyedvectors.Vocab at 0x1a287e3eb8>,
#  'schepen': <gensim.models.keyedvectors.Vocab at 0x1a287e3ef0>,
#  'produkten': <gensim.models.keyedvectors.Vocab at 0x1a287e3f28>,
#  'jaren': <gensim.models.keyedvectors.Vocab at 0x1a287e3f60>,
#  'lang': <gensim.models.keyedvectors.Vocab at 0x1a287e3f98>,
#  'zulke': <gensim.models.keyedvectors.Vocab at 0x1a287e3fd0>,
#  'effecten': <gensim.models.keyedvectors.Vocab at 0x1a287e7048>,
#  'desastreuze': <gensim.models.keyedvectors.Vocab at 0x1a287e7080>,
#  'gevolgen': <gensim.models.keyedvectors.Vocab at 0x1a287e70b8>,
#  'gehad': <gensim.models.keyedvectors.Vocab at 0x1a287e70f0>,
#  'als': <gensim.models.keyedvectors.Vocab at 0x1a287e7128>,
#  'talloze': <gensim.models.keyedvectors.Vocab at 0x1a287e7160>,
#  'beweerd': <gensim.models.keyedvectors.Vocab at 0x1a287e7198>,
#  'onrechte': <gensim.models.keyedvectors.Vocab at 0x1a287e71d0>,
#  'kamen': <gensim.models.keyedvectors.Vocab at 0x1a287e7208>,
#  'visie': <gensim.models.keyedvectors.Vocab at 0x1a287e7240>,
#  'gedoopt': <gensim.models.keyedvectors.Vocab at 0x1a287e7278>,
#  'bom': <gensim.models.keyedvectors.Vocab at 0x1a287e72b0>,
#  'onder': <gensim.models.keyedvectors.Vocab at 0x1a287e72e8>,
#  'geschapen': <gensim.models.keyedvectors.Vocab at 0x1a287e7320>,
#  'bouwwerk': <gensim.models.keyedvectors.Vocab at 0x1a287e7358>,
#  'zoals': <gensim.models.keyedvectors.Vocab at 0x1a287e7390>,
#  'goed': <gensim.models.keyedvectors.Vocab at 0x1a287e73c8>,
#  'beseft': <gensim.models.keyedvectors.Vocab at 0x1a287e7400>,
#  'bedrijvigheid': <gensim.models.keyedvectors.Vocab at 0x1a287e7438>,
#  'diverse': <gensim.models.keyedvectors.Vocab at 0x1a287e7470>,
#  'lotgevallen': <gensim.models.keyedvectors.Vocab at 0x1a287e74a8>,
#  'allerlei': <gensim.models.keyedvectors.Vocab at 0x1a287e74e0>,
#  'sectoren': <gensim.models.keyedvectors.Vocab at 0x1a287e7518>,
#  'ervan': <gensim.models.keyedvectors.Vocab at 0x1a287e7550>,
#  'beide': <gensim.models.keyedvectors.Vocab at 0x1a287e7588>,
#  'staten': <gensim.models.keyedvectors.Vocab at 0x1a287e75c0>,
#  'zo': <gensim.models.keyedvectors.Vocab at 0x1a287e75f8>,
#  'vastgeketend': <gensim.models.keyedvectors.Vocab at 0x1a287e7630>,
#  'veronderstelde': <gensim.models.keyedvectors.Vocab at 0x1a287e7668>,
#  'verregaande': <gensim.models.keyedvectors.Vocab at 0x1a287e76a0>,
#  'doelmatigheid': <gensim.models.keyedvectors.Vocab at 0x1a287e76d8>,
#  'bestuur': <gensim.models.keyedvectors.Vocab at 0x1a287e7710>,
#  'werk': <gensim.models.keyedvectors.Vocab at 0x1a287e7748>,
#  'ermee': <gensim.models.keyedvectors.Vocab at 0x1a287e7780>,
#  'staat': <gensim.models.keyedvectors.Vocab at 0x1a287e77b8>,
#  'valt': <gensim.models.keyedvectors.Vocab at 0x1a287e77f0>,
#  'ondanks': <gensim.models.keyedvectors.Vocab at 0x1a287e7828>,
#  'vertoon': <gensim.models.keyedvectors.Vocab at 0x1a287e7860>,
#  'eruditie': <gensim.models.keyedvectors.Vocab at 0x1a287e7898>,
#  'intel': <gensim.models.keyedvectors.Vocab at 0x1a287e78d0>,
#  'ligentie': <gensim.models.keyedvectors.Vocab at 0x1a287e7908>,
#  'argumentatie': <gensim.models.keyedvectors.Vocab at 0x1a287e7940>,
#  'twijfelachtig': <gensim.models.keyedvectors.Vocab at 0x1a287e7978>,
#  'kan': <gensim.models.keyedvectors.Vocab at 0x1a287e79b0>,
#  'accepteren': <gensim.models.keyedvectors.Vocab at 0x1a287e79e8>,
#  'eco': <gensim.models.keyedvectors.Vocab at 0x1a287e7a20>,
#  'nomische': <gensim.models.keyedvectors.Vocab at 0x1a287e7a58>,
#  'dieper': <gensim.models.keyedvectors.Vocab at 0x1a287e7a90>,
#  'ingegrepen': <gensim.models.keyedvectors.Vocab at 0x1a287e7ac8>,
#  'dan': <gensim.models.keyedvectors.Vocab at 0x1a287e7b00>,
#  'toe': <gensim.models.keyedvectors.Vocab at 0x1a287e7b38>,
#  'dacht': <gensim.models.keyedvectors.Vocab at 0x1a287e7b70>,
#  'echter': <gensim.models.keyedvectors.Vocab at 0x1a287e7ba8>,
#  'deugdelijk': <gensim.models.keyedvectors.Vocab at 0x1a287e7be0>,
#  'bewijs': <gensim.models.keyedvectors.Vocab at 0x1a287e7c18>,
#  'aanvaarden': <gensim.models.keyedvectors.Vocab at 0x1a287e7c50>,
#  'kooplie': <gensim.models.keyedvectors.Vocab at 0x1a287e7c88>,
#  'creatief': <gensim.models.keyedvectors.Vocab at 0x1a287e7cc0>,
#  'aanpassingsproces': <gensim.models.keyedvectors.Vocab at 0x1a287e7cf8>,
#  'zi': <gensim.models.keyedvectors.Vocab at 0x1a287e7d30>,
#  'jn': <gensim.models.keyedvectors.Vocab at 0x1a287e7d68>,
#  'geweest': <gensim.models.keyedvectors.Vocab at 0x1a287e7da0>,
#  'meeste': <gensim.models.keyedvectors.Vocab at 0x1a287e7dd8>,
#  'gemakkelijk': <gensim.models.keyedvectors.Vocab at 0x1a287e7e10>,
#  'komen': <gensim.models.keyedvectors.Vocab at 0x1a287e7e48>,
#  'althans': <gensim.models.keyedvectors.Vocab at 0x1a287e7e80>,
#  'fase': <gensim.models.keyedvectors.Vocab at 0x1a287e7eb8>,
#  'opgang': <gensim.models.keyedvectors.Vocab at 0x1a287e7ef0>,
#  'al': <gensim.models.keyedvectors.Vocab at 0x1a287e7f28>,
#  'le': <gensim.models.keyedvectors.Vocab at 0x1a287e7f60>,
#  'oorlogen': <gensim.models.keyedvectors.Vocab at 0x1a287e7f98>,
#  'verklaart': <gensim.models.keyedvectors.Vocab at 0x1a287e7fd0>,
#  'geringe': <gensim.models.keyedvectors.Vocab at 0x1a287eb048>,
#  'bereidheid': <gensim.models.keyedvectors.Vocab at 0x1a287eb080>,
#  'conces': <gensim.models.keyedvectors.Vocab at 0x1a287eb0b8>,
#  'sies': <gensim.models.keyedvectors.Vocab at 0x1a287eb0f0>,
#  'madrid': <gensim.models.keyedvectors.Vocab at 0x1a287eb128>,
#  'doen': <gensim.models.keyedvectors.Vocab at 0x1a287eb160>,
#  'werkt': <gensim.models.keyedvectors.Vocab at 0x1a287eb198>,
#  'verder': <gensim.models.keyedvectors.Vocab at 0x1a287eb1d0>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x1a287eb208>,
#  'gabriel': <gensim.models.keyedvectors.Vocab at 0x1a287eb240>,
#  'roy': <gensim.models.keyedvectors.Vocab at 0x1a287eb278>,
#  'waals': <gensim.models.keyedvectors.Vocab at 0x1a287eb2b0>,
#  'edelman': <gensim.models.keyedvectors.Vocab at 0x1a287eb2e8>,
#  'almirantazgo': <gensim.models.keyedvectors.Vocab at 0x1a287eb320>,
#  'poten': <gensim.models.keyedvectors.Vocab at 0x1a287eb358>,
#  'hielp': <gensim.models.keyedvectors.Vocab at 0x1a287eb390>,
#  'zetten': <gensim.models.keyedvectors.Vocab at 0x1a287eb3c8>,
#  'manuel': <gensim.models.keyedvectors.Vocab at 0x1a287eb400>,
#  'pez': <gensim.models.keyedvectors.Vocab at 0x1a287eb438>,
#  'pereira': <gensim.models.keyedvectors.Vocab at 0x1a287eb470>,
#  'portugese': <gensim.models.keyedvectors.Vocab at 0x1a287eb4a8>,
#  'jood': <gensim.models.keyedvectors.Vocab at 0x1a287eb4e0>,
#  'hof': <gensim.models.keyedvectors.Vocab at 0x1a287eb518>,
#  'adviseerde': <gensim.models.keyedvectors.Vocab at 0x1a287eb550>,
#  'vierde': <gensim.models.keyedvectors.Vocab at 0x1a287eb588>,
#  'samenhang': <gensim.models.keyedvectors.Vocab at 0x1a287eb5c0>,
#  'race': <gensim.models.keyedvectors.Vocab at 0x1a287eb5f8>,
#  'class': <gensim.models.keyedvectors.Vocab at 0x1a287eb630>,
#  'politics': <gensim.models.keyedvectors.Vocab at 0x1a287eb668>,
#  'colonial': <gensim.models.keyedvectors.Vocab at 0x1a287eb6a0>,
#  'meesterlijk': <gensim.models.keyedvectors.Vocab at 0x1a287eb6d8>,
#  'bekende': <gensim.models.keyedvectors.Vocab at 0x1a287eb710>,
#  'general': <gensim.models.keyedvectors.Vocab at 0x1a287eb748>,
#  'crisis': <gensim.models.keyedvectors.Vocab at 0x1a287eb780>,
#  'ogen': <gensim.models.keyedvectors.Vocab at 0x1a287eb7b8>,
#  'beleefde': <gensim.models.keyedvectors.Vocab at 0x1a287eb7f0>,
#  'nieuw': <gensim.models.keyedvectors.Vocab at 0x1a287eb828>,
#  'spanje': <gensim.models.keyedvectors.Vocab at 0x1a287eb860>,
#  'plaats': <gensim.models.keyedvectors.Vocab at 0x1a287eb898>,
#  'lynch': <gensim.models.keyedvectors.Vocab at 0x1a287eb8d0>,
#  'hoge': <gensim.models.keyedvectors.Vocab at 0x1a287eb908>,
#  'belastingen': <gensim.models.keyedvectors.Vocab at 0x1a287eb940>,
#  'verdediging': <gensim.models.keyedvectors.Vocab at 0x1a287eb978>,
#  'gebied': <gensim.models.keyedvectors.Vocab at 0x1a287eb9b0>,
#  'zelf': <gensim.models.keyedvectors.Vocab at 0x1a287eb9e8>,
#  'spanningen': <gensim.models.keyedvectors.Vocab at 0x1a287eba20>,
#  'werden': <gensim.models.keyedvectors.Vocab at 0x1a287eba58>,
#  'primair': <gensim.models.keyedvectors.Vocab at 0x1a287eba90>,
#  'opgeroepen': <gensim.models.keyedvectors.Vocab at 0x1a287ebac8>,
#  'diepgaande': <gensim.models.keyedvectors.Vocab at 0x1a287ebb00>,
#  'tegenstellingen': <gensim.models.keyedvectors.Vocab at 0x1a287ebb38>,
#  'bureaucraten': <gensim.models.keyedvectors.Vocab at 0x1a287ebb70>,
#  ...}

# %%
model.wv.most_similar('blij')
# Out:
# [('huis_bouwt', 0.46296414732933044),
#  ('irredentisme_neigende', 0.46283066272735596),
#  ('verheugd', 0.43626224994659424),
#  ('iedereen', 0.42347609996795654),
#  ('vertrouwel_k', 0.41994571685791016),
#  ('hem_welgevallige', 0.4166860580444336),
#  ('komen_opzoeken', 0.4148625135421753),
#  ('wetenschap_voorstelde', 0.4142054319381714),
#  ('zooeven_geciteerde', 0.4096190333366394),
#  ('tevreden', 0.40937539935112)]

# %%
#model.save('/tmp/model_1975')
model_1975 = gensim.models.Word2Vec.load('/tmp/model_1975')

# %%
model.most_similar('kernoorlog')
# Out:
# /Users/melvinwevers/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('ooorlog', 0.7695426940917969),
#  ('turkenoorlog', 0.7669199705123901),
#  ('tenoorlog', 0.7650911211967468),
#  ('ettenoorlog', 0.7451728582382202),
#  ('toorlog', 0.743453860282898),
#  ('fransenoorlog', 0.7289604544639587),
#  ('bondgenotenoorlog', 0.6941068172454834),
#  ('oorlog', 0.6889581680297852),
#  ('rassenoorlog', 0.6740708947181702),
#  ('tarievenoorlog', 0.6712789535522461)]

# %%
#model = gensim.models.Word2Vec(min_count=10, size = 200, iter=10, alpha=0.025, window = 10, workers = 7)
model.build_vocab(sentences_1985, update=True)
model.train(sentences_1985, total_examples=model.corpus_count, epochs=model.iter)
#model.init_sims(replace=True)

# %%
#model_1975.most_similar('man')
model.most_similar('man')

# %%
def _getRelatedTerms(model, seedTerms, maxRelatedTerms):
    queries = []
    threads = []

    for term in seedTerms:
        t = threading.Thread(target=_getRelatedTermsThread,
                             args=(model, term, maxRelatedTerms, queries))
        threads.append(t)
        t.start()
    for t in threads:
        t.join()
    queries.sort()
    return queries

def _getRelatedTermsThread(model, term, maxRelatedTerms, queries,
                           ):
    try:
        newTerms = model.most_similar(term, topn=maxRelatedTerms)

        # list.append is thread safe, so we should be ok
        queries.append((term, newTerms))
    except KeyError:
        queries.append((term, []))
        pass

def _pruned(pairs, words):
    '''Returns a list of (word, weight) tuples which is the same as the given
    list (pairs), except containing only words in the set (words)'''
    return [(word, weight) for word, weight in pairs if word in words]


def _getCommonTerms(terms, N):
    '''Return a the top N terms of the given list. Terms are given as a
    dictionary of { term: weight } and the top terms are the terms with the
    highest weights.'''
    termCounter = Counter(terms)
    topTerms = termCounter.most_common(N)
    return topTerms

# %%
def _trackCore(model, seedTerms, maxTerms=250, maxRelatedTerms=10,
                   minSim=0.4, wordBoost=1.0, reward=lambda x: 1.0):
        '''Given a list of seed terms, queries the given model to produce a
        list of terms. A dictionary of links is also returned as a dictionary:
        { seed: [(word,weight),...]}'''
        dRelatedTerms = defaultdict(float)
        links = defaultdict(list)

        relatedTermQueries = _getRelatedTerms(
            model, seedTerms, maxRelatedTerms)

        # Get the first tier related terms
        for term, newTerms in relatedTermQueries:
            # The terms are always related to themselves
            dRelatedTerms[term] = wordBoost
            links[term].append((term, 0.0))

            for newTerm, tSim in newTerms:
                if tSim < minSim:
                    break
                dRelatedTerms[newTerm] += reward(tSim)
                links[term].append((newTerm, tSim))

        # Select the top N terms with biggest weights (where N=maxTerms)
        topTerms = _getCommonTerms(dRelatedTerms, maxTerms)

        selectedTerms = set(word for word, weight in topTerms)
        links = {seed: _pruned(pairs, selectedTerms)
                 for seed, pairs in links.items()}
        return topTerms, links

# %%
seedTerms = ['president']

# %%
_trackCore(model_1985, seedTerms)

# %%
women_vector = 0
for term in topTerms:
    women_vector += model_vk[term[0]]

# %%
model_vk.similar_by_vector(women_vector, topn=20, restrict_vocab=None)

# %%
annoy_index = AnnoyIndexer(model, 1000)

# %%
model_nrc.most_similar(['politiek'], topn=15)

# %%
model_vk.most_similar(['politiek'], topn=15, indexer=annoy_index)

# %%
def get_vec(model, word):
    if word in model.vocab:
        vec = model[word]
    else:
        vec = None
    return vec

# %%
#cosine similarity two words
model.wv.similarity('amerika', 'oorlog')

# %%
model.wv.n_similarity(['amerika','president'],['mens','abortus'])

# %%
model.wv.doesnt_match(['amerika','frisdrank','president'])

# %%
#model.most_similar(positive=['vrouw'], negative=['man'], topn=50)
model.most_similar(positive=['man'], negative=['vrouw'], topn=50)

# %%
model.most_similar(positive=['vrouw', 'vrouwen','man','mannen'], topn=50)

# %%
her_tokens = [token for token,weight in model.wv.most_similar(positive=['vrouw'], negative=['man'], topn=50)]

# %%
her_tokens

# %%
# Get the vector for each sampled word
vectors = [model[word] for word in her_tokens]

# %%
from sklearn.metrics import pairwise
dist_matrix = pairwise.pairwise_distances(vectors, metric='cosine')

# %%
from sklearn.manifold import MDS
mds = MDS(n_components = 2, dissimilarity='precomputed')
embeddings = mds.fit_transform(dist_matrix)

# %%
import matplotlib.pyplot as plt
_, ax = plt.subplots(figsize=(10,10))
ax.scatter(embeddings[:,0], embeddings[:,1], alpha=0)
for i in range(len(vectors)):
    ax.annotate(her_tokens[i], ((embeddings[i,0], embeddings[i,1])))

# %%
# Create functions that reject vectors, find nearest words

def vector_rejector(model, word1, word2):
    vector1 = model[word1]
    vector2 = model[word2]
    # Rejects vector_2 from vector_1
    # Note that vectors are passed in, not words; also mean of
    # several vectors could be passed as a single argument
    projection = np.dot(vector1,vector2) * vector2
    return vector1 - projection

# %%
she_vector = vector_rejector(model, 'vrouw', 'man')

# %%
model.similar_by_vector(she_vector, topn=20, restrict_vocab=None)
